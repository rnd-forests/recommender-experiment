# %%
import os
import sys
from rs import parse_config

path = parse_config(section='Path', key='package')
module = os.path.expanduser(path)
if os.path.exists(module) and module not in sys.path:
    sys.path.append(module)

# %% [markdown]
# ### Visualizing Viblo post view logs

# %%
# %matplotlib inline
# %run experiments/visualize_viblo_views.py
# Out:
# Original Data (With IP addresses)
# (434153, 3)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 434153 entries, 0 to 434152
# Data columns (total 3 columns):
# UserID    434153 non-null object
# ItemID    434153 non-null int64
# Rating    434153 non-null float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 9.9+ MB
# None
#
#               ItemID         Rating
# count  434153.000000  434153.000000
# mean     7164.086723       1.511373
# std      4265.672255       1.900837
# min         3.000000       1.000000
# 25%      3626.000000       1.000000
# 50%      7901.000000       1.000000
# 75%     11012.000000       2.000000
# max     14248.000000     238.000000
#
# Modified data (Without IP addresses)
# (422710, 3)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 422710 entries, 0 to 422709
# Data columns (total 3 columns):
# UserID    422710 non-null int64
# ItemID    422710 non-null int64
# Rating    422710 non-null int64
# dtypes: int64(3)
# memory usage: 9.7 MB
# None
#
#               UserID         ItemID         Rating
# count  422710.000000  422710.000000  422710.000000
# mean    10034.889570    7048.901625       1.522263
# std      5322.797642    4227.539354       1.924042
# min         2.000000       3.000000       1.000000
# 25%      7489.000000    3566.000000       1.000000
# 50%     11646.000000    7792.000000       1.000000
# 75%     14209.000000   10822.000000       2.000000
# max     16878.000000   14248.000000     238.000000

# %% [markdown]
# ### Testing on Viblo implicit data (post views)

# %%
# %run experiments/viblo_views.py
# Out:
# ■ ■ ■ SVD ■ ■ ■
# ■ Performing random sampling on the dataset
# ■ Training using trainset
# Processing epoch 0
# Processing epoch 1
# Processing epoch 2
# Processing epoch 3
# Processing epoch 4
# Processing epoch 5
# Processing epoch 6
# Processing epoch 7
# Processing epoch 8
# Processing epoch 9
# Processing epoch 10
# Processing epoch 11
# Processing epoch 12
# Processing epoch 13
# Processing epoch 14
# Processing epoch 15
# Processing epoch 16
# Processing epoch 17
# Processing epoch 18
# Processing epoch 19
# ■ Evaluating using testset
# RMSE: 1.9592
# ■ Using the best estimator on the full dataset
# Processing epoch 0
# Processing epoch 1
# Processing epoch 2
# Processing epoch 3
# Processing epoch 4
# Processing epoch 5
# Processing epoch 6
# Processing epoch 7
# Processing epoch 8
# Processing epoch 9
# Processing epoch 10
# Processing epoch 11
# Processing epoch 12
# Processing epoch 13
# Processing epoch 14
# Processing epoch 15
# Processing epoch 16
# Processing epoch 17
# Processing epoch 18
# Processing epoch 19
# ■ Accuracy scores
# MAE:  0.3750
# RMSE: 1.1364
# ■ Precision and Recall
# |           |      1087 |
# |-----------+-----------|
# | Precision | 0.866667  |
# | Recall    | 0.0878378 |
# ■ Time elapsed: 0:00:37
# ■ Recommendations:
# | 1087                            |
# |---------------------------------|
# | {'iid': '5470', 'est': '9.99'}  |
# | {'iid': '1993', 'est': '9.98'}  |
# | {'iid': '4242', 'est': '9.97'}  |
# | {'iid': '12757', 'est': '9.82'} |
# | {'iid': '12757', 'est': '9.82'} |
# | {'iid': '3786', 'est': '9.74'}  |
# | {'iid': '8659', 'est': '9.71'}  |
# | {'iid': '117', 'est': '9.71'}   |
# | {'iid': '1860', 'est': '9.71'}  |
# | {'iid': '7259', 'est': '9.64'}  |
# | {'iid': '7259', 'est': '9.64'}  |
# | {'iid': '8375', 'est': '9.64'}  |
# | {'iid': '7259', 'est': '9.64'}  |
# | {'iid': '7643', 'est': '9.57'}  |
# | {'iid': '6869', 'est': '9.56'}  |

# %% [markdown]
# ### Testing on Viblo explicit data (votes and clips)

# %%
# %run experiments/viblo.py
# Out:
# ■ Voting data
# ■ ■ ■ SVD ■ ■ ■
# ■ Performing random sampling on the dataset
# ■ Performing Grid Search
# ------------
# Parameters combination 1 of 4
# params:  {'n_epochs': 20, 'n_factors': 20}
# ------------
# Mean RMSE: 0.4257
# ------------
# ------------
# Parameters combination 2 of 4
# params:  {'n_epochs': 20, 'n_factors': 50}
# ------------
# Mean RMSE: 0.4292
# ------------
# ------------
# Parameters combination 3 of 4
# params:  {'n_epochs': 30, 'n_factors': 20}
# ------------
# Mean RMSE: 0.4222
# ------------
# ------------
# Parameters combination 4 of 4
# params:  {'n_epochs': 30, 'n_factors': 50}
# ------------
# Mean RMSE: 0.4244
# ------------
# ■ Grid Search summary
# |     RMSE |   n_epochs | params                            |
# |----------+------------+-----------------------------------|
# | 0.422166 |         30 | {'n_epochs': 30, 'n_factors': 20} |
# | 0.424408 |         30 | {'n_epochs': 30, 'n_factors': 50} |
# | 0.425702 |         20 | {'n_epochs': 20, 'n_factors': 20} |
# | 0.429245 |         20 | {'n_epochs': 20, 'n_factors': 50} |
# ■ Algorithm properties
# surprise.prediction_algorithms.matrix_factorization.SVD at 0x7fcd6f5a7ef0 (
#     biased = True,
#     bsl_options = {},
#     init_mean = 0,
#     init_std_dev = 0.1,
#     lr_bi = 0.005,
#     ...,
#     reg_pu = 0.02,
#     reg_qi = 0.02,
#     sim_options = {'user_based': True},
#     verbose = False
# )
# ■ Training using trainset
# Processing epoch 0
# Processing epoch 1
# Processing epoch 2
# Processing epoch 3
# Processing epoch 4
# Processing epoch 5
# Processing epoch 6
# Processing epoch 7
# Processing epoch 8
# Processing epoch 9
# Processing epoch 10
# Processing epoch 11
# Processing epoch 12
# Processing epoch 13
# Processing epoch 14
# Processing epoch 15
# Processing epoch 16
# Processing epoch 17
# Processing epoch 18
# Processing epoch 19
# Processing epoch 20
# Processing epoch 21
# Processing epoch 22
# Processing epoch 23
# Processing epoch 24
# Processing epoch 25
# Processing epoch 26
# Processing epoch 27
# Processing epoch 28
# Processing epoch 29
# ■ Evaluating using testset
# RMSE: 0.3982
# ■ Using the best estimator on the full dataset
# Processing epoch 0
# Processing epoch 1
# Processing epoch 2
# Processing epoch 3
# Processing epoch 4
# Processing epoch 5
# Processing epoch 6
# Processing epoch 7
# Processing epoch 8
# Processing epoch 9
# Processing epoch 10
# Processing epoch 11
# Processing epoch 12
# Processing epoch 13
# Processing epoch 14
# Processing epoch 15
# Processing epoch 16
# Processing epoch 17
# Processing epoch 18
# Processing epoch 19
# Processing epoch 20
# Processing epoch 21
# Processing epoch 22
# Processing epoch 23
# Processing epoch 24
# Processing epoch 25
# Processing epoch 26
# Processing epoch 27
# Processing epoch 28
# Processing epoch 29
# ■ Saving the trained model
# The dump has been saved as file /home/vinhnguyen/code/recommender/experiments/saved/viblo_votes
# ■ Accuracy scores
# MAE:  0.0930
# RMSE: 0.1367
# ■ Precision and Recall
# |           |         2 |         21 |          9 |
# |-----------+-----------+------------+------------|
# | Precision | 1         | 1          | 1          |
# | Recall    | 0.0113507 | 0.00607533 | 0.00600962 |
# ■ Time elapsed: 0:01:02
# ■ Recommendations:
# | 2                               | 21                              | 9                               |
# |---------------------------------+---------------------------------+---------------------------------|
# | {'iid': '8027', 'est': '1.00'}  | {'iid': '11759', 'est': '0.85'} | {'iid': '8027', 'est': '1.00'}  |
# | {'iid': '9554', 'est': '1.00'}  | {'iid': '11533', 'est': '0.85'} | {'iid': '9554', 'est': '1.00'}  |
# | {'iid': '8461', 'est': '1.00'}  | {'iid': '8203', 'est': '0.83'}  | {'iid': '8461', 'est': '1.00'}  |
# | {'iid': '3882', 'est': '1.00'}  | {'iid': '11742', 'est': '0.82'} | {'iid': '9638', 'est': '1.00'}  |
# | {'iid': '11912', 'est': '1.00'} | {'iid': '8965', 'est': '0.81'}  | {'iid': '11912', 'est': '1.00'} |
# | {'iid': '8502', 'est': '1.00'}  | {'iid': '10436', 'est': '0.80'} | {'iid': '8502', 'est': '1.00'}  |
# | {'iid': '10952', 'est': '1.00'} | {'iid': '9852', 'est': '0.80'}  | {'iid': '10254', 'est': '1.00'} |
# | {'iid': '11639', 'est': '1.00'} | {'iid': '11586', 'est': '0.80'} | {'iid': '4948', 'est': '1.00'}  |
# | {'iid': '8458', 'est': '1.00'}  | {'iid': '11136', 'est': '0.79'} | {'iid': '10682', 'est': '1.00'} |
# | {'iid': '4229', 'est': '1.00'}  | {'iid': '9751', 'est': '0.79'}  | {'iid': '10812', 'est': '1.00'} |
#
# ■ Clipping data
# ■ ■ ■ SVD ■ ■ ■
# ■ Performing random sampling on the dataset
# ■ Performing Grid Search
# ------------
# Parameters combination 1 of 4
# params:  {'n_epochs': 20, 'n_factors': 20}
# ------------
# Mean RMSE: 0.2863
# ------------
# ------------
# Parameters combination 2 of 4
# params:  {'n_epochs': 20, 'n_factors': 50}
# ------------
# Mean RMSE: 0.2883
# ------------
# ------------
# Parameters combination 3 of 4
# params:  {'n_epochs': 30, 'n_factors': 20}
# ------------
# Mean RMSE: 0.2859
# ------------
# ------------
# Parameters combination 4 of 4
# params:  {'n_epochs': 30, 'n_factors': 50}
# ------------
# Mean RMSE: 0.2875
# ------------
# ■ Grid Search summary
# |     RMSE |   n_epochs | params                            |
# |----------+------------+-----------------------------------|
# | 0.285935 |         30 | {'n_epochs': 30, 'n_factors': 20} |
# | 0.286255 |         20 | {'n_epochs': 20, 'n_factors': 20} |
# | 0.28754  |         30 | {'n_epochs': 30, 'n_factors': 50} |
# | 0.288289 |         20 | {'n_epochs': 20, 'n_factors': 50} |
# ■ Algorithm properties
# surprise.prediction_algorithms.matrix_factorization.SVD at 0x7fcd74e4b4e0 (
#     biased = True,
#     bsl_options = {},
#     init_mean = 0,
#     init_std_dev = 0.1,
#     lr_bi = 0.005,
#     ...,
#     reg_pu = 0.02,
#     reg_qi = 0.02,
#     sim_options = {'user_based': True},
#     verbose = False
# )
# ■ Training using trainset
# Processing epoch 0
# Processing epoch 1
# Processing epoch 2
# Processing epoch 3
# Processing epoch 4
# Processing epoch 5
# Processing epoch 6
# Processing epoch 7
# Processing epoch 8
# Processing epoch 9
# Processing epoch 10
# Processing epoch 11
# Processing epoch 12
# Processing epoch 13
# Processing epoch 14
# Processing epoch 15
# Processing epoch 16
# Processing epoch 17
# Processing epoch 18
# Processing epoch 19
# Processing epoch 20
# Processing epoch 21
# Processing epoch 22
# Processing epoch 23
# Processing epoch 24
# Processing epoch 25
# Processing epoch 26
# Processing epoch 27
# Processing epoch 28
# Processing epoch 29
# ■ Evaluating using testset
# RMSE: 0.2791
# ■ Using the best estimator on the full dataset
# Processing epoch 0
# Processing epoch 1
# Processing epoch 2
# Processing epoch 3
# Processing epoch 4
# Processing epoch 5
# Processing epoch 6
# Processing epoch 7
# Processing epoch 8
# Processing epoch 9
# Processing epoch 10
# Processing epoch 11
# Processing epoch 12
# Processing epoch 13
# Processing epoch 14
# Processing epoch 15
# Processing epoch 16
# Processing epoch 17
# Processing epoch 18
# Processing epoch 19
# Processing epoch 20
# Processing epoch 21
# Processing epoch 22
# Processing epoch 23
# Processing epoch 24
# Processing epoch 25
# Processing epoch 26
# Processing epoch 27
# Processing epoch 28
# Processing epoch 29
# ■ Saving the trained model
# The dump has been saved as file /home/vinhnguyen/code/recommender/experiments/saved/viblo_clips
# ■ Accuracy scores
# MAE:  0.0768
# RMSE: 0.0953
# ■ Precision and Recall
# |           |   12825 |   13072 |   2 |
# |-----------+---------+---------+-----|
# | Precision |       0 |       1 |   0 |
# | Recall    |       1 |       1 |   1 |
# ■ Time elapsed: 0:01:15
# ■ Recommendations:
# | 12825                           | 13072                           | 2                               |
# |---------------------------------+---------------------------------+---------------------------------|
# | {'iid': '8093', 'est': '1.00'}  | {'iid': '10938', 'est': '0.51'} | {'iid': '10682', 'est': '1.00'} |
# | {'iid': '10384', 'est': '1.00'} | {'iid': '11842', 'est': '0.47'} | {'iid': '8093', 'est': '1.00'}  |
# | {'iid': '8866', 'est': '1.00'}  | {'iid': '1944', 'est': '0.47'}  | {'iid': '7614', 'est': '1.00'}  |
# | {'iid': '9942', 'est': '1.00'}  | {'iid': '10515', 'est': '0.46'} | {'iid': '9146', 'est': '1.00'}  |
# | {'iid': '11639', 'est': '1.00'} | {'iid': '9331', 'est': '0.46'}  | {'iid': '4242', 'est': '1.00'}  |
# | {'iid': '8539', 'est': '1.00'}  | {'iid': '9554', 'est': '0.45'}  | {'iid': '10384', 'est': '1.00'} |
# | {'iid': '11661', 'est': '1.00'} | {'iid': '8861', 'est': '0.45'}  | {'iid': '11509', 'est': '1.00'} |
# | {'iid': '7780', 'est': '1.00'}  | {'iid': '10859', 'est': '0.44'} | {'iid': '10878', 'est': '1.00'} |
# | {'iid': '12030', 'est': '1.00'} | {'iid': '8691', 'est': '0.44'}  | {'iid': '3725', 'est': '1.00'}  |
# | {'iid': '11339', 'est': '1.00'} | {'iid': '12030', 'est': '0.44'} | {'iid': '4596', 'est': '1.00'}  |
