# %%
import os
import sys
from rs import parse_config

path = parse_config(section='Path', key='package')
module = os.path.expanduser(path)
if os.path.exists(module) and module not in sys.path:
    sys.path.append(module)

# %% [markdown]
# ### Testing on Viblo explicit data

# %%
# %run experiments/viblo.py
# Out:
# ■ Voting data
# ■ ■ ■ SVD ■ ■ ■
# ■ Performing random sampling on the dataset
# ■ Performing Grid Search
# ------------
# Parameters combination 1 of 12
# params:  {'n_epochs': 20, 'n_factors': 20, 'reg_all': 0.01}
# ------------
# Mean RMSE: 0.4253
# ------------
# ------------
# Parameters combination 2 of 12
# params:  {'n_epochs': 20, 'n_factors': 20, 'reg_all': 0.02}
# ------------
# Mean RMSE: 0.4261
# ------------
# ------------
# Parameters combination 3 of 12
# params:  {'n_epochs': 20, 'n_factors': 50, 'reg_all': 0.01}
# ------------
# Mean RMSE: 0.4267
# ------------
# ------------
# Parameters combination 4 of 12
# params:  {'n_epochs': 20, 'n_factors': 50, 'reg_all': 0.02}
# ------------
# Mean RMSE: 0.4267
# ------------
# ------------
# Parameters combination 5 of 12
# params:  {'n_epochs': 30, 'n_factors': 20, 'reg_all': 0.01}
# ------------
# Mean RMSE: 0.4225
# ------------
# ------------
# Parameters combination 6 of 12
# params:  {'n_epochs': 30, 'n_factors': 20, 'reg_all': 0.02}
# ------------
# Mean RMSE: 0.4218
# ------------
# ------------
# Parameters combination 7 of 12
# params:  {'n_epochs': 30, 'n_factors': 50, 'reg_all': 0.01}
# ------------
# Mean RMSE: 0.4222
# ------------
# ------------
# Parameters combination 8 of 12
# params:  {'n_epochs': 30, 'n_factors': 50, 'reg_all': 0.02}
# ------------
# Mean RMSE: 0.4226
# ------------
# ------------
# Parameters combination 9 of 12
# params:  {'n_epochs': 50, 'n_factors': 20, 'reg_all': 0.01}
# ------------
# Mean RMSE: 0.4187
# ------------
# ------------
# Parameters combination 10 of 12
# params:  {'n_epochs': 50, 'n_factors': 20, 'reg_all': 0.02}
# ------------
# Mean RMSE: 0.4184
# ------------
# ------------
# Parameters combination 11 of 12
# params:  {'n_epochs': 50, 'n_factors': 50, 'reg_all': 0.01}
# ------------
# Mean RMSE: 0.4223
# ------------
# ------------
# Parameters combination 12 of 12
# params:  {'n_epochs': 50, 'n_factors': 50, 'reg_all': 0.02}
# ------------
# Mean RMSE: 0.4198
# ------------
# ■ Grid Search completed. Here is the summary:
#         RMSE  n_epochs                                             params  \
# 9   0.418389        50  {'n_epochs': 50, 'n_factors': 20, 'reg_all': 0...
# 8   0.418696        50  {'n_epochs': 50, 'n_factors': 20, 'reg_all': 0...
# 11  0.419779        50  {'n_epochs': 50, 'n_factors': 50, 'reg_all': 0...
# 5   0.421848        30  {'n_epochs': 30, 'n_factors': 20, 'reg_all': 0...
# 6   0.422212        30  {'n_epochs': 30, 'n_factors': 50, 'reg_all': 0...
# 10  0.422253        50  {'n_epochs': 50, 'n_factors': 50, 'reg_all': 0...
# 4   0.422455        30  {'n_epochs': 30, 'n_factors': 20, 'reg_all': 0...
# 7   0.422550        30  {'n_epochs': 30, 'n_factors': 50, 'reg_all': 0...
# 0   0.425343        20  {'n_epochs': 20, 'n_factors': 20, 'reg_all': 0...
# 1   0.426137        20  {'n_epochs': 20, 'n_factors': 20, 'reg_all': 0...
# 3   0.426658        20  {'n_epochs': 20, 'n_factors': 50, 'reg_all': 0...
# 2   0.426663        20  {'n_epochs': 20, 'n_factors': 50, 'reg_all': 0...
#
#                       scores
# 9   {'RMSE': 0.418389083644}
# 8   {'RMSE': 0.418696114614}
# 11   {'RMSE': 0.41977920946}
# 5   {'RMSE': 0.421847577698}
# 6   {'RMSE': 0.422211855165}
# 10  {'RMSE': 0.422253193165}
# 4   {'RMSE': 0.422455147071}
# 7    {'RMSE': 0.42255047099}
# 0    {'RMSE': 0.42534349171}
# 1   {'RMSE': 0.426136998669}
# 3   {'RMSE': 0.426657586868}
# 2   {'RMSE': 0.426663244367}
# ■ Algorithm properties:
# surprise.prediction_algorithms.matrix_factorization.SVD at 0x7ff5ec1a9eb8 (
#     biased = True,
#     bsl_options = {},
#     init_mean = 0,
#     init_std_dev = 0.1,
#     lr_bi = 0.005,
#     ...,
#     reg_pu = 0.02,
#     reg_qi = 0.02,
#     sim_options = {'user_based': True},
#     verbose = True
# )
# ■ Training using trainset
# Processing epoch 0
# Processing epoch 1
# Processing epoch 2
# Processing epoch 3
# Processing epoch 4
# Processing epoch 5
# Processing epoch 6
# Processing epoch 7
# Processing epoch 8
# Processing epoch 9
# Processing epoch 10
# Processing epoch 11
# Processing epoch 12
# Processing epoch 13
# Processing epoch 14
# Processing epoch 15
# Processing epoch 16
# Processing epoch 17
# Processing epoch 18
# Processing epoch 19
# Processing epoch 20
# Processing epoch 21
# Processing epoch 22
# Processing epoch 23
# Processing epoch 24
# Processing epoch 25
# Processing epoch 26
# Processing epoch 27
# Processing epoch 28
# Processing epoch 29
# Processing epoch 30
# Processing epoch 31
# Processing epoch 32
# Processing epoch 33
# Processing epoch 34
# Processing epoch 35
# Processing epoch 36
# Processing epoch 37
# Processing epoch 38
# Processing epoch 39
# Processing epoch 40
# Processing epoch 41
# Processing epoch 42
# Processing epoch 43
# Processing epoch 44
# Processing epoch 45
# Processing epoch 46
# Processing epoch 47
# Processing epoch 48
# Processing epoch 49
# ■ Evaluating using testset
# RMSE: 0.3966
# ■ Using the best estimator on full dataset
# ■ Saving the trained model
# The dump has been saved as file /home/local/FRAMGIA/nguyen.ngoc.vinh/code/recommender/experiments/trained_models/viblo_votes
# ■ Accuracy scores:
# MAE:  0.1193
# RMSE: 0.1803
# ■ Time elapsed: 0:00:22
# ■ Recommendations:
# |    | 2                               | 21                              | 9                               |
# |----+---------------------------------+---------------------------------+---------------------------------|
# |  0 | {'est': '1.00', 'iid': '9195'}  | {'est': '0.99', 'iid': '12013'} | {'est': '1.00', 'iid': '11314'} |
# |  1 | {'est': '1.00', 'iid': '3198'}  | {'est': '0.96', 'iid': '10972'} | {'est': '1.00', 'iid': '9195'}  |
# |  2 | {'est': '1.00', 'iid': '8027'}  | {'est': '0.93', 'iid': '8158'}  | {'est': '1.00', 'iid': '11168'} |
# |  3 | {'est': '1.00', 'iid': '10006'} | {'est': '0.92', 'iid': '3419'}  | {'est': '1.00', 'iid': '3198'}  |
# |  4 | {'est': '1.00', 'iid': '10376'} | {'est': '0.91', 'iid': '692'}   | {'est': '1.00', 'iid': '8027'}  |
# |  5 | {'est': '1.00', 'iid': '9386'}  | {'est': '0.90', 'iid': '9869'}  | {'est': '1.00', 'iid': '10006'} |
# |  6 | {'est': '1.00', 'iid': '4370'}  | {'est': '0.90', 'iid': '9178'}  | {'est': '1.00', 'iid': '10376'} |
# |  7 | {'est': '1.00', 'iid': '8290'}  | {'est': '0.90', 'iid': '2222'}  | {'est': '1.00', 'iid': '9386'}  |
# |  8 | {'est': '1.00', 'iid': '9572'}  | {'est': '0.90', 'iid': '9556'}  | {'est': '1.00', 'iid': '4370'}  |
# |  9 | {'est': '1.00', 'iid': '8728'}  | {'est': '0.90', 'iid': '11258'} | {'est': '1.00', 'iid': '8290'}  |
#
# ■ Clipping data
# ■ ■ ■ SVD ■ ■ ■
# ■ Performing random sampling on the dataset
# ■ Performing Grid Search
# ------------
# Parameters combination 1 of 4
# params:  {'n_epochs': 20, 'n_factors': 20}
# ------------
# Mean RMSE: 0.2827
# ------------
# ------------
# Parameters combination 2 of 4
# params:  {'n_epochs': 20, 'n_factors': 50}
# ------------
# Mean RMSE: 0.2849
# ------------
# ------------
# Parameters combination 3 of 4
# params:  {'n_epochs': 30, 'n_factors': 20}
# ------------
# Mean RMSE: 0.2818
# ------------
# ------------
# Parameters combination 4 of 4
# params:  {'n_epochs': 30, 'n_factors': 50}
# ------------
# Mean RMSE: 0.2838
# ------------
# ■ Grid Search completed. Here is the summary:
#        RMSE  n_epochs                             params  \
# 2  0.281773        30  {'n_epochs': 30, 'n_factors': 20}
# 0  0.282677        20  {'n_epochs': 20, 'n_factors': 20}
# 3  0.283764        30  {'n_epochs': 30, 'n_factors': 50}
# 1  0.284903        20  {'n_epochs': 20, 'n_factors': 50}
#
#                      scores
# 2  {'RMSE': 0.281773189117}
# 0  {'RMSE': 0.282676547022}
# 3  {'RMSE': 0.283764133498}
# 1  {'RMSE': 0.284903362683}
# ■ Algorithm properties:
# surprise.prediction_algorithms.matrix_factorization.SVD at 0x7ff5c03a3630 (
#     biased = True,
#     bsl_options = {},
#     init_mean = 0,
#     init_std_dev = 0.1,
#     lr_bi = 0.005,
#     ...,
#     reg_pu = 0.02,
#     reg_qi = 0.02,
#     sim_options = {'user_based': True},
#     verbose = True
# )
# ■ Training using trainset
# Processing epoch 0
# Processing epoch 1
# Processing epoch 2
# Processing epoch 3
# Processing epoch 4
# Processing epoch 5
# Processing epoch 6
# Processing epoch 7
# Processing epoch 8
# Processing epoch 9
# Processing epoch 10
# Processing epoch 11
# Processing epoch 12
# Processing epoch 13
# Processing epoch 14
# Processing epoch 15
# Processing epoch 16
# Processing epoch 17
# Processing epoch 18
# Processing epoch 19
# Processing epoch 20
# Processing epoch 21
# Processing epoch 22
# Processing epoch 23
# Processing epoch 24
# Processing epoch 25
# Processing epoch 26
# Processing epoch 27
# Processing epoch 28
# Processing epoch 29
# ■ Evaluating using testset
# RMSE: 0.2957
# ■ Using the best estimator on full dataset
# ■ Saving the trained model
# The dump has been saved as file /home/local/FRAMGIA/nguyen.ngoc.vinh/code/recommender/experiments/trained_models/viblo_clips
# ■ Accuracy scores:
# MAE:  0.0769
# RMSE: 0.0964
# ■ Time elapsed: 0:00:29
# ■ Recommendations:
# |    | 12825                           | 13072                           | 2                               |
# |----+---------------------------------+---------------------------------+---------------------------------|
# |  0 | {'est': '1.00', 'iid': '11825'} | {'est': '0.48', 'iid': '9058'}  | {'est': '1.00', 'iid': '11825'} |
# |  1 | {'est': '1.00', 'iid': '8736'}  | {'est': '0.48', 'iid': '9234'}  | {'est': '1.00', 'iid': '6724'}  |
# |  2 | {'est': '1.00', 'iid': '8159'}  | {'est': '0.46', 'iid': '11842'} | {'est': '1.00', 'iid': '227'}   |
# |  3 | {'est': '1.00', 'iid': '10066'} | {'est': '0.46', 'iid': '10806'} | {'est': '1.00', 'iid': '9638'}  |
# |  4 | {'est': '1.00', 'iid': '5754'}  | {'est': '0.45', 'iid': '6112'}  | {'est': '1.00', 'iid': '3053'}  |
# |  5 | {'est': '1.00', 'iid': '11489'} | {'est': '0.44', 'iid': '11511'} | {'est': '1.00', 'iid': '11580'} |
# |  6 | {'est': '1.00', 'iid': '9386'}  | {'est': '0.44', 'iid': '7557'}  | {'est': '1.00', 'iid': '9331'}  |
# |  7 | {'est': '1.00', 'iid': '822'}   | {'est': '0.44', 'iid': '12008'} | {'est': '1.00', 'iid': '5486'}  |
# |  8 | {'est': '1.00', 'iid': '11573'} | {'est': '0.43', 'iid': '9597'}  | {'est': '1.00', 'iid': '2664'}  |
# |  9 | {'est': '1.00', 'iid': '11400'} | {'est': '0.43', 'iid': '8736'}  | {'est': '1.00', 'iid': '9042'}  |
