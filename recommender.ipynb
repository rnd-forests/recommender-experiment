# %%
import os
import sys
from rs import parse_config

path = parse_config(section='Path', key='package')
module = os.path.expanduser(path)
if os.path.exists(module) and module not in sys.path:
    sys.path.append(module)

# %% [markdown]
# ### BaselineOnly

# %%
# %run experiments/baseline_only.py
# Out:
# ■ ■ ■ BaselineOnly ■ ■ ■
# ■ Performing random sampling on the dataset
# ■ Performing Grid Search
# ------------
# Parameters combination 1 of 2
# params:  {'bsl_options': {'method': 'als', 'n_epochs': 30}}
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# ------------
# Mean RMSE: 0.9466
# ------------
# ------------
# Parameters combination 2 of 2
# params:  {'bsl_options': {'method': 'sgd', 'learning_rate': 0.0007}}
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# ------------
# Mean RMSE: 0.9737
# ------------
# ■ Grid Search summary
# |     RMSE | bsl_options                                | params                                                      |
# |----------+--------------------------------------------+-------------------------------------------------------------|
# | 0.946617 | {'method': 'als', 'n_epochs': 30}          | {'bsl_options': {'method': 'als', 'n_epochs': 30}}          |
# | 0.973691 | {'method': 'sgd', 'learning_rate': 0.0007} | {'bsl_options': {'method': 'sgd', 'learning_rate': 0.0007}} |
# ■ Algorithm properties
# surprise.prediction_algorithms.baseline_only.BaselineOnly at 0x7f9620002320 (
#     bsl_options = {'method': 'als', 'n_epochs': 30},
#     sim_options = {'user_based': True}
# )
# ■ Training using trainset
# Estimating biases using als...
# ■ Evaluating using testset
# RMSE: 0.9494
# ■ Using the best estimator on the full dataset
# Estimating biases using als...
# ■ Saving the trained model
# The dump has been saved as file /home/vinhnguyen/code/recommender/experiments/saved/baseline_only
# ■ Accuracy scores
# MAE:  0.3900
# RMSE: 0.4977
# ■ Precision and Recall
# |           |          1 |          2 |          3 |
# |-----------+------------+------------+------------|
# | Precision | 1          | 1          | 1          |
# | Recall    | 0.00703235 | 0.00629723 | 0.00625391 |
# ■ Time elapsed: 0:00:56
# ■ Recommendations:
# | 1                             | 2                             | 3                             |
# |-------------------------------+-------------------------------+-------------------------------|
# | {'iid': '408', 'est': '4.47'} | {'iid': '408', 'est': '4.58'} | {'iid': '408', 'est': '4.15'} |
# | {'iid': '318', 'est': '4.45'} | {'iid': '64', 'est': '4.57'}  | {'iid': '64', 'est': '4.14'}  |
# | {'iid': '483', 'est': '4.44'} | {'iid': '318', 'est': '4.56'} | {'iid': '483', 'est': '4.12'} |
# | {'iid': '603', 'est': '4.34'} | {'iid': '483', 'est': '4.55'} | {'iid': '169', 'est': '4.12'} |
# | {'iid': '480', 'est': '4.28'} | {'iid': '169', 'est': '4.55'} | {'iid': '50', 'est': '4.04'}  |
# | {'iid': '657', 'est': '4.28'} | {'iid': '12', 'est': '4.46'}  | {'iid': '12', 'est': '4.03'}  |
# | {'iid': '357', 'est': '4.27'} | {'iid': '603', 'est': '4.45'} | {'iid': '603', 'est': '4.01'} |
# | {'iid': '479', 'est': '4.27'} | {'iid': '178', 'est': '4.43'} | {'iid': '127', 'est': '4.00'} |
# | {'iid': '427', 'est': '4.26'} | {'iid': '480', 'est': '4.39'} | {'iid': '178', 'est': '4.00'} |
# | {'iid': '511', 'est': '4.23'} | {'iid': '657', 'est': '4.39'} | {'iid': '272', 'est': '3.96'} |

# %% [markdown]
# ### CoClustering

# %%
# %run experiments/co_clustering.py
# Out:
# ■ ■ ■ CoClustering ■ ■ ■
# ■ Performing random sampling on the dataset
# ■ Performing Grid Search
# ------------
# Parameters combination 1 of 8
# params:  {'n_cltr_i': 3, 'n_epochs': 20, 'n_cltr_u': 3}
# ------------
# Mean RMSE: 0.9807
# ------------
# ------------
# Parameters combination 2 of 8
# params:  {'n_cltr_i': 3, 'n_epochs': 20, 'n_cltr_u': 5}
# ------------
# Mean RMSE: 0.9763
# ------------
# ------------
# Parameters combination 3 of 8
# params:  {'n_cltr_i': 3, 'n_epochs': 60, 'n_cltr_u': 3}
# ------------
# Mean RMSE: 0.9794
# ------------
# ------------
# Parameters combination 4 of 8
# params:  {'n_cltr_i': 3, 'n_epochs': 60, 'n_cltr_u': 5}
# ------------
# Mean RMSE: 0.9737
# ------------
# ------------
# Parameters combination 5 of 8
# params:  {'n_cltr_i': 5, 'n_epochs': 20, 'n_cltr_u': 3}
# ------------
# Mean RMSE: 0.9822
# ------------
# ------------
# Parameters combination 6 of 8
# params:  {'n_cltr_i': 5, 'n_epochs': 20, 'n_cltr_u': 5}
# ------------
# Mean RMSE: 0.9867
# ------------
# ------------
# Parameters combination 7 of 8
# params:  {'n_cltr_i': 5, 'n_epochs': 60, 'n_cltr_u': 3}
# ------------
# Mean RMSE: 0.9770
# ------------
# ------------
# Parameters combination 8 of 8
# params:  {'n_cltr_i': 5, 'n_epochs': 60, 'n_cltr_u': 5}
# ------------
# Mean RMSE: 0.9859
# ------------
# ■ Grid Search summary
# |     RMSE |   n_cltr_i | params                                         |
# |----------+------------+------------------------------------------------|
# | 0.973747 |          3 | {'n_cltr_i': 3, 'n_epochs': 60, 'n_cltr_u': 5} |
# | 0.976345 |          3 | {'n_cltr_i': 3, 'n_epochs': 20, 'n_cltr_u': 5} |
# | 0.976999 |          5 | {'n_cltr_i': 5, 'n_epochs': 60, 'n_cltr_u': 3} |
# | 0.97937  |          3 | {'n_cltr_i': 3, 'n_epochs': 60, 'n_cltr_u': 3} |
# | 0.9807   |          3 | {'n_cltr_i': 3, 'n_epochs': 20, 'n_cltr_u': 3} |
# | 0.982169 |          5 | {'n_cltr_i': 5, 'n_epochs': 20, 'n_cltr_u': 3} |
# | 0.985858 |          5 | {'n_cltr_i': 5, 'n_epochs': 60, 'n_cltr_u': 5} |
# | 0.986668 |          5 | {'n_cltr_i': 5, 'n_epochs': 20, 'n_cltr_u': 5} |
# ■ Algorithm properties
# surprise.prediction_algorithms.co_clustering.CoClustering at 0x7f95e890f5f8 (
#     bsl_options = {},
#     n_cltr_i = 3,
#     n_cltr_u = 5,
#     n_epochs = 60,
#     sim_options = {'user_based': True},
#     verbose = False
# )
# ■ Training using trainset
# Processing epoch 0
# Processing epoch 1
# Processing epoch 2
# Processing epoch 3
# Processing epoch 4
# Processing epoch 5
# Processing epoch 6
# Processing epoch 7
# Processing epoch 8
# Processing epoch 9
# Processing epoch 10
# Processing epoch 11
# Processing epoch 12
# Processing epoch 13
# Processing epoch 14
# Processing epoch 15
# Processing epoch 16
# Processing epoch 17
# Processing epoch 18
# Processing epoch 19
# Processing epoch 20
# Processing epoch 21
# Processing epoch 22
# Processing epoch 23
# Processing epoch 24
# Processing epoch 25
# Processing epoch 26
# Processing epoch 27
# Processing epoch 28
# Processing epoch 29
# Processing epoch 30
# Processing epoch 31
# Processing epoch 32
# Processing epoch 33
# Processing epoch 34
# Processing epoch 35
# Processing epoch 36
# Processing epoch 37
# Processing epoch 38
# Processing epoch 39
# Processing epoch 40
# Processing epoch 41
# Processing epoch 42
# Processing epoch 43
# Processing epoch 44
# Processing epoch 45
# Processing epoch 46
# Processing epoch 47
# Processing epoch 48
# Processing epoch 49
# Processing epoch 50
# Processing epoch 51
# Processing epoch 52
# Processing epoch 53
# Processing epoch 54
# Processing epoch 55
# Processing epoch 56
# Processing epoch 57
# Processing epoch 58
# Processing epoch 59
# ■ Evaluating using testset
# RMSE: 0.9560
# ■ Using the best estimator on the full dataset
# Processing epoch 0
# Processing epoch 1
# Processing epoch 2
# Processing epoch 3
# Processing epoch 4
# Processing epoch 5
# Processing epoch 6
# Processing epoch 7
# Processing epoch 8
# Processing epoch 9
# Processing epoch 10
# Processing epoch 11
# Processing epoch 12
# Processing epoch 13
# Processing epoch 14
# Processing epoch 15
# Processing epoch 16
# Processing epoch 17
# Processing epoch 18
# Processing epoch 19
# Processing epoch 20
# Processing epoch 21
# Processing epoch 22
# Processing epoch 23
# Processing epoch 24
# Processing epoch 25
# Processing epoch 26
# Processing epoch 27
# Processing epoch 28
# Processing epoch 29
# Processing epoch 30
# Processing epoch 31
# Processing epoch 32
# Processing epoch 33
# Processing epoch 34
# Processing epoch 35
# Processing epoch 36
# Processing epoch 37
# Processing epoch 38
# Processing epoch 39
# Processing epoch 40
# Processing epoch 41
# Processing epoch 42
# Processing epoch 43
# Processing epoch 44
# Processing epoch 45
# Processing epoch 46
# Processing epoch 47
# Processing epoch 48
# Processing epoch 49
# Processing epoch 50
# Processing epoch 51
# Processing epoch 52
# Processing epoch 53
# Processing epoch 54
# Processing epoch 55
# Processing epoch 56
# Processing epoch 57
# Processing epoch 58
# Processing epoch 59
# ■ Saving the trained model
# The dump has been saved as file /home/vinhnguyen/code/recommender/experiments/saved/co_clustering
# ■ Accuracy scores
# MAE:  0.7880
# RMSE: 1.0106
# ■ Precision and Recall
# |           |          1 |          2 |          3 |
# |-----------+------------+------------+------------|
# | Precision | 1          | 1          | 1          |
# | Recall    | 0.00696379 | 0.00621891 | 0.00621504 |
# ■ Time elapsed: 0:00:58
# ■ Recommendations:
# | 1                              | 2                              | 3                              |
# |--------------------------------+--------------------------------+--------------------------------|
# | {'iid': '1293', 'est': '5.00'} | {'iid': '1293', 'est': '5.00'} | {'iid': '1191', 'est': '4.41'} |
# | {'iid': '1191', 'est': '5.00'} | {'iid': '814', 'est': '5.00'}  | {'iid': '1201', 'est': '4.41'} |
# | {'iid': '1201', 'est': '5.00'} | {'iid': '1189', 'est': '5.00'} | {'iid': '1500', 'est': '4.41'} |
# | {'iid': '1500', 'est': '5.00'} | {'iid': '1599', 'est': '5.00'} | {'iid': '1653', 'est': '4.41'} |
# | {'iid': '1189', 'est': '5.00'} | {'iid': '1122', 'est': '5.00'} | {'iid': '1467', 'est': '4.41'} |
# | {'iid': '1599', 'est': '5.00'} | {'iid': '1450', 'est': '5.00'} | {'iid': '1398', 'est': '4.41'} |
# | {'iid': '1653', 'est': '5.00'} | {'iid': '1191', 'est': '4.95'} | {'iid': '814', 'est': '4.40'}  |
# | {'iid': '1467', 'est': '5.00'} | {'iid': '1201', 'est': '4.95'} | {'iid': '1122', 'est': '4.40'} |
# | {'iid': '1398', 'est': '5.00'} | {'iid': '1500', 'est': '4.95'} | {'iid': '1449', 'est': '4.12'} |
# | {'iid': '1450', 'est': '5.00'} | {'iid': '1653', 'est': '4.95'} | {'iid': '851', 'est': '4.06'}  |

# %% [markdown]
# ### KNNBaseline

# %%
# %run experiments/knn_baseline.py
# Out:
# ■ ■ ■ KNNBaseline ■ ■ ■
# ■ Performing random sampling on the dataset
# ■ Performing Grid Search
# ------------
# Parameters combination 1 of 8
# params:  {'bsl_options': {'method': 'als'}, 'sim_options': {'name': 'cosine'}, 'k': 20}
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9484
# ------------
# ------------
# Parameters combination 2 of 8
# params:  {'bsl_options': {'method': 'als'}, 'sim_options': {'name': 'cosine', 'user_based': True}, 'k': 40}
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9427
# ------------
# ------------
# Parameters combination 3 of 8
# params:  {'bsl_options': {'method': 'sgd', 'learning_rate': 0.0007}, 'sim_options': {'name': 'cosine', 'user_based': True}, 'k': 20}
# Estimating biases using sgd...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9586
# ------------
# ------------
# Parameters combination 4 of 8
# params:  {'bsl_options': {'method': 'sgd', 'learning_rate': 0.0007}, 'sim_options': {'name': 'cosine', 'user_based': True}, 'k': 40}
# Estimating biases using sgd...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9526
# ------------
# ------------
# Parameters combination 5 of 8
# params:  {'bsl_options': {'method': 'als'}, 'sim_options': {'name': 'pearson_baseline'}, 'k': 20}
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9377
# ------------
# ------------
# Parameters combination 6 of 8
# params:  {'bsl_options': {'method': 'als'}, 'sim_options': {'name': 'pearson_baseline', 'user_based': True}, 'k': 40}
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9354
# ------------
# ------------
# Parameters combination 7 of 8
# params:  {'bsl_options': {'method': 'sgd', 'learning_rate': 0.0007}, 'sim_options': {'name': 'pearson_baseline', 'user_based': True}, 'k': 20}
# Estimating biases using sgd...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9424
# ------------
# ------------
# Parameters combination 8 of 8
# params:  {'bsl_options': {'method': 'sgd', 'learning_rate': 0.0007}, 'sim_options': {'name': 'pearson_baseline', 'user_based': True}, 'k': 40}
# Estimating biases using sgd...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9403
# ------------
# ■ Grid Search summary
# |     RMSE | bsl_options                                | params                                                                                                                                |
# |----------+--------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------|
# | 0.935431 | {'method': 'als'}                          | {'bsl_options': {'method': 'als'}, 'sim_options': {'name': 'pearson_baseline', 'user_based': True}, 'k': 40}                          |
# | 0.937663 | {'method': 'als'}                          | {'bsl_options': {'method': 'als'}, 'sim_options': {'name': 'pearson_baseline', 'user_based': True}, 'k': 20}                          |
# | 0.940259 | {'method': 'sgd', 'learning_rate': 0.0007} | {'bsl_options': {'method': 'sgd', 'learning_rate': 0.0007}, 'sim_options': {'name': 'pearson_baseline', 'user_based': True}, 'k': 40} |
# | 0.942369 | {'method': 'sgd', 'learning_rate': 0.0007} | {'bsl_options': {'method': 'sgd', 'learning_rate': 0.0007}, 'sim_options': {'name': 'pearson_baseline', 'user_based': True}, 'k': 20} |
# | 0.942704 | {'method': 'als'}                          | {'bsl_options': {'method': 'als'}, 'sim_options': {'name': 'cosine', 'user_based': True}, 'k': 40}                                    |
# | 0.948419 | {'method': 'als'}                          | {'bsl_options': {'method': 'als'}, 'sim_options': {'name': 'cosine', 'user_based': True}, 'k': 20}                                    |
# | 0.95259  | {'method': 'sgd', 'learning_rate': 0.0007} | {'bsl_options': {'method': 'sgd', 'learning_rate': 0.0007}, 'sim_options': {'name': 'cosine', 'user_based': True}, 'k': 40}           |
# | 0.958571 | {'method': 'sgd', 'learning_rate': 0.0007} | {'bsl_options': {'method': 'sgd', 'learning_rate': 0.0007}, 'sim_options': {'name': 'cosine', 'user_based': True}, 'k': 20}           |
# ■ Algorithm properties
# surprise.prediction_algorithms.knns.KNNBaseline at 0x7f9650291e80 (
#     bsl_options = {'method': 'als'},
#     k = 40,
#     min_k = 1,
#     sim_options = {'name': 'pearson_baseline', 'user_based': True}
# )
# ■ Training using trainset
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# ■ Evaluating using testset
# RMSE: 0.9174
# ■ Using the best estimator on the full dataset
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# ■ Saving the trained model
# The dump has been saved as file /home/vinhnguyen/code/recommender/experiments/saved/knn_baseline
# ■ Accuracy scores
# MAE:  0.6340
# RMSE: 0.8204
# ■ Precision and Recall
# |           |          1 |         2 |          3 |
# |-----------+------------+-----------+------------|
# | Precision | 1          | 1         | 1          |
# | Recall    | 0.00697837 | 0.0062383 | 0.00619195 |
# ■ Time elapsed: 0:03:03
# ■ Recommendations:
# | 1                              | 2                              | 3                              |
# |--------------------------------+--------------------------------+--------------------------------|
# | {'iid': '851', 'est': '5.00'}  | {'iid': '851', 'est': '5.00'}  | {'iid': '851', 'est': '5.00'}  |
# | {'iid': '909', 'est': '5.00'}  | {'iid': '868', 'est': '5.00'}  | {'iid': '1512', 'est': '5.00'} |
# | {'iid': '868', 'est': '5.00'}  | {'iid': '1512', 'est': '5.00'} | {'iid': '1449', 'est': '5.00'} |
# | {'iid': '1529', 'est': '5.00'} | {'iid': '1639', 'est': '5.00'} | {'iid': '1643', 'est': '5.00'} |
# | {'iid': '1302', 'est': '5.00'} | {'iid': '1449', 'est': '5.00'} | {'iid': '1368', 'est': '4.93'} |
# | {'iid': '1558', 'est': '5.00'} | {'iid': '1629', 'est': '5.00'} | {'iid': '1429', 'est': '4.93'} |
# | {'iid': '1193', 'est': '5.00'} | {'iid': '1358', 'est': '5.00'} | {'iid': '1591', 'est': '4.86'} |
# | {'iid': '1367', 'est': '5.00'} | {'iid': '1463', 'est': '5.00'} | {'iid': '1491', 'est': '4.78'} |
# | {'iid': '1628', 'est': '5.00'} | {'iid': '1643', 'est': '5.00'} | {'iid': '1629', 'est': '4.75'} |
# | {'iid': '1495', 'est': '5.00'} | {'iid': '1599', 'est': '5.00'} | {'iid': '1500', 'est': '4.72'} |

# %% [markdown]
# ### KNNBasic

# %%
# %run experiments/knn_basic.py
# Out:
# ■ ■ ■ KNNBasic ■ ■ ■
# ■ Performing random sampling on the dataset
# ■ Performing Grid Search
# ------------
# Parameters combination 1 of 10
# params:  {'sim_options': {'name': 'msd'}, 'k': 20}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9893
# ------------
# ------------
# Parameters combination 2 of 10
# params:  {'sim_options': {'name': 'msd', 'user_based': True}, 'k': 40}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9898
# ------------
# ------------
# Parameters combination 3 of 10
# params:  {'sim_options': {'name': 'cosine'}, 'k': 20}
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 1.0294
# ------------
# ------------
# Parameters combination 4 of 10
# params:  {'sim_options': {'name': 'cosine', 'user_based': True}, 'k': 40}
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 1.0216
# ------------
# ------------
# Parameters combination 5 of 10
# params:  {'sim_options': {'name': 'pearson'}, 'k': 20}
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 1.0283
# ------------
# ------------
# Parameters combination 6 of 10
# params:  {'sim_options': {'name': 'pearson', 'user_based': True}, 'k': 40}
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 1.0211
# ------------
# ------------
# Parameters combination 7 of 10
# params:  {'sim_options': {'name': 'pearson_baseline'}, 'k': 20}
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 1.0131
# ------------
# ------------
# Parameters combination 8 of 10
# params:  {'sim_options': {'name': 'pearson_baseline', 'user_based': True}, 'k': 40}
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 1.0105
# ------------
# ------------
# Parameters combination 9 of 10
# params:  {'sim_options': {'name': 'pearson_baseline', 'shrinkage': 150}, 'k': 20}
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 1.0130
# ------------
# ------------
# Parameters combination 10 of 10
# params:  {'sim_options': {'name': 'pearson_baseline', 'shrinkage': 150, 'user_based': True}, 'k': 40}
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 1.0105
# ------------
# ■ Grid Search summary
# |     RMSE | params                                                                                       | sim_options                                                        |
# |----------+----------------------------------------------------------------------------------------------+--------------------------------------------------------------------|
# | 0.989262 | {'sim_options': {'name': 'msd', 'user_based': True}, 'k': 20}                                | {'name': 'msd', 'user_based': True}                                |
# | 0.989789 | {'sim_options': {'name': 'msd', 'user_based': True}, 'k': 40}                                | {'name': 'msd', 'user_based': True}                                |
# | 1.01051  | {'sim_options': {'name': 'pearson_baseline', 'user_based': True}, 'k': 40}                   | {'name': 'pearson_baseline', 'user_based': True}                   |
# | 1.01053  | {'sim_options': {'name': 'pearson_baseline', 'shrinkage': 150, 'user_based': True}, 'k': 40} | {'name': 'pearson_baseline', 'shrinkage': 150, 'user_based': True} |
# | 1.01305  | {'sim_options': {'name': 'pearson_baseline', 'shrinkage': 150, 'user_based': True}, 'k': 20} | {'name': 'pearson_baseline', 'shrinkage': 150, 'user_based': True} |
# | 1.01309  | {'sim_options': {'name': 'pearson_baseline', 'user_based': True}, 'k': 20}                   | {'name': 'pearson_baseline', 'user_based': True}                   |
# | 1.02109  | {'sim_options': {'name': 'pearson', 'user_based': True}, 'k': 40}                            | {'name': 'pearson', 'user_based': True}                            |
# | 1.02161  | {'sim_options': {'name': 'cosine', 'user_based': True}, 'k': 40}                             | {'name': 'cosine', 'user_based': True}                             |
# | 1.02832  | {'sim_options': {'name': 'pearson', 'user_based': True}, 'k': 20}                            | {'name': 'pearson', 'user_based': True}                            |
# | 1.02943  | {'sim_options': {'name': 'cosine', 'user_based': True}, 'k': 20}                             | {'name': 'cosine', 'user_based': True}                             |
# ■ Algorithm properties
# surprise.prediction_algorithms.knns.KNNBasic at 0x7f95feae82b0 (
#     bsl_options = {},
#     k = 20,
#     min_k = 1,
#     sim_options = {'name': 'msd', 'user_based': True}
# )
# ■ Training using trainset
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ■ Evaluating using testset
# RMSE: 0.9798
# ■ Using the best estimator on the full dataset
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ■ Saving the trained model
# The dump has been saved as file /home/vinhnguyen/code/recommender/experiments/saved/knn_basic
# ■ Accuracy scores
# MAE:  0.6999
# RMSE: 0.9285
# ■ Precision and Recall
# |           |          1 |          2 |          3 |
# |-----------+------------+------------+------------|
# | Precision | 1          | 1          | 1          |
# | Recall    | 0.00693001 | 0.00622665 | 0.00621504 |
# ■ Time elapsed: 0:02:25
# ■ Recommendations:
# | 1                              | 2                              | 3                              |
# |--------------------------------+--------------------------------+--------------------------------|
# | {'iid': '1653', 'est': '5.00'} | {'iid': '1653', 'est': '5.00'} | {'iid': '1653', 'est': '5.00'} |
# | {'iid': '1122', 'est': '5.00'} | {'iid': '1122', 'est': '5.00'} | {'iid': '1467', 'est': '5.00'} |
# | {'iid': '1467', 'est': '5.00'} | {'iid': '1467', 'est': '5.00'} | {'iid': '1144', 'est': '5.00'} |
# | {'iid': '1144', 'est': '5.00'} | {'iid': '1144', 'est': '5.00'} | {'iid': '1500', 'est': '5.00'} |
# | {'iid': '1500', 'est': '5.00'} | {'iid': '1500', 'est': '5.00'} | {'iid': '814', 'est': '5.00'}  |
# | {'iid': '814', 'est': '5.00'}  | {'iid': '814', 'est': '5.00'}  | {'iid': '1293', 'est': '5.00'} |
# | {'iid': '1293', 'est': '5.00'} | {'iid': '1293', 'est': '5.00'} | {'iid': '1189', 'est': '5.00'} |
# | {'iid': '1189', 'est': '5.00'} | {'iid': '1189', 'est': '5.00'} | {'iid': '1449', 'est': '4.72'} |
# | {'iid': '1592', 'est': '4.78'} | {'iid': '483', 'est': '4.80'}  | {'iid': '1643', 'est': '4.60'} |
# | {'iid': '513', 'est': '4.75'}  | {'iid': '474', 'est': '4.75'}  | {'iid': '178', 'est': '4.53'}  |

# %% [markdown]
# ### KNNWithMeans

# %%
# %run experiments/knn_with_means.py
# Out:
# ■ ■ ■ KNNWithMeans ■ ■ ■
# ■ Performing random sampling on the dataset
# ■ Performing Grid Search
# ------------
# Parameters combination 1 of 10
# params:  {'sim_options': {'name': 'msd'}, 'k': 20}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9655
# ------------
# ------------
# Parameters combination 2 of 10
# params:  {'sim_options': {'name': 'msd', 'user_based': True}, 'k': 40}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9585
# ------------
# ------------
# Parameters combination 3 of 10
# params:  {'sim_options': {'name': 'cosine'}, 'k': 20}
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9727
# ------------
# ------------
# Parameters combination 4 of 10
# params:  {'sim_options': {'name': 'cosine', 'user_based': True}, 'k': 40}
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9634
# ------------
# ------------
# Parameters combination 5 of 10
# params:  {'sim_options': {'name': 'pearson'}, 'k': 20}
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9668
# ------------
# ------------
# Parameters combination 6 of 10
# params:  {'sim_options': {'name': 'pearson', 'user_based': True}, 'k': 40}
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9592
# ------------
# ------------
# Parameters combination 7 of 10
# params:  {'sim_options': {'name': 'pearson_baseline'}, 'k': 20}
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9527
# ------------
# ------------
# Parameters combination 8 of 10
# params:  {'sim_options': {'name': 'pearson_baseline', 'user_based': True}, 'k': 40}
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9505
# ------------
# ------------
# Parameters combination 9 of 10
# params:  {'sim_options': {'name': 'pearson_baseline', 'shrinkage': 150}, 'k': 20}
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9526
# ------------
# ------------
# Parameters combination 10 of 10
# params:  {'sim_options': {'name': 'pearson_baseline', 'shrinkage': 150, 'user_based': True}, 'k': 40}
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9503
# ------------
# ■ Grid Search summary
# |     RMSE | params                                                                                       | sim_options                                                        |
# |----------+----------------------------------------------------------------------------------------------+--------------------------------------------------------------------|
# | 0.950277 | {'sim_options': {'name': 'pearson_baseline', 'shrinkage': 150, 'user_based': True}, 'k': 40} | {'name': 'pearson_baseline', 'shrinkage': 150, 'user_based': True} |
# | 0.950478 | {'sim_options': {'name': 'pearson_baseline', 'user_based': True}, 'k': 40}                   | {'name': 'pearson_baseline', 'user_based': True}                   |
# | 0.952578 | {'sim_options': {'name': 'pearson_baseline', 'shrinkage': 150, 'user_based': True}, 'k': 20} | {'name': 'pearson_baseline', 'shrinkage': 150, 'user_based': True} |
# | 0.952674 | {'sim_options': {'name': 'pearson_baseline', 'user_based': True}, 'k': 20}                   | {'name': 'pearson_baseline', 'user_based': True}                   |
# | 0.958528 | {'sim_options': {'name': 'msd', 'user_based': True}, 'k': 40}                                | {'name': 'msd', 'user_based': True}                                |
# | 0.959171 | {'sim_options': {'name': 'pearson', 'user_based': True}, 'k': 40}                            | {'name': 'pearson', 'user_based': True}                            |
# | 0.963357 | {'sim_options': {'name': 'cosine', 'user_based': True}, 'k': 40}                             | {'name': 'cosine', 'user_based': True}                             |
# | 0.965498 | {'sim_options': {'name': 'msd', 'user_based': True}, 'k': 20}                                | {'name': 'msd', 'user_based': True}                                |
# | 0.96684  | {'sim_options': {'name': 'pearson', 'user_based': True}, 'k': 20}                            | {'name': 'pearson', 'user_based': True}                            |
# | 0.972709 | {'sim_options': {'name': 'cosine', 'user_based': True}, 'k': 20}                             | {'name': 'cosine', 'user_based': True}                             |
# ■ Algorithm properties
# surprise.prediction_algorithms.knns.KNNWithMeans at 0x7f95feae8400 (
#     bsl_options = {},
#     k = 40,
#     min_k = 1,
#     sim_options = {'name': 'pearson_baseline', 'shrinkage': 150, 'user_based': True}
# )
# ■ Training using trainset
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# ■ Evaluating using testset
# RMSE: 0.9373
# ■ Using the best estimator on the full dataset
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# ■ Saving the trained model
# The dump has been saved as file /home/vinhnguyen/code/recommender/experiments/saved/knn_with_means
# ■ Accuracy scores
# MAE:  0.6392
# RMSE: 0.8228
# ■ Precision and Recall
# |           |          1 |          2 |          3 |
# |-----------+------------+------------+------------|
# | Precision | 1          | 1          | 1          |
# | Recall    | 0.00697837 | 0.00623053 | 0.00619579 |
# ■ Time elapsed: 0:02:51
# ■ Recommendations:
# | 1                              | 2                              | 3                              |
# |--------------------------------+--------------------------------+--------------------------------|
# | {'iid': '909', 'est': '5.00'}  | {'iid': '867', 'est': '5.00'}  | {'iid': '1643', 'est': '4.68'} |
# | {'iid': '1628', 'est': '5.00'} | {'iid': '1463', 'est': '5.00'} | {'iid': '1394', 'est': '4.43'} |
# | {'iid': '1193', 'est': '5.00'} | {'iid': '814', 'est': '5.00'}  | {'iid': '1175', 'est': '4.17'} |
# | {'iid': '1558', 'est': '5.00'} | {'iid': '1629', 'est': '5.00'} | {'iid': '1591', 'est': '4.05'} |
# | {'iid': '1405', 'est': '5.00'} | {'iid': '1639', 'est': '5.00'} | {'iid': '1512', 'est': '4.04'} |
# | {'iid': '851', 'est': '5.00'}  | {'iid': '1467', 'est': '5.00'} | {'iid': '1500', 'est': '4.02'} |
# | {'iid': '848', 'est': '5.00'}  | {'iid': '1554', 'est': '5.00'} | {'iid': '1429', 'est': '3.96'} |
# | {'iid': '814', 'est': '5.00'}  | {'iid': '1155', 'est': '4.99'} | {'iid': '119', 'est': '3.96'}  |
# | {'iid': '1642', 'est': '5.00'} | {'iid': '1405', 'est': '4.95'} | {'iid': '884', 'est': '3.93'}  |
# | {'iid': '1629', 'est': '5.00'} | {'iid': '1293', 'est': '4.94'} | {'iid': '1302', 'est': '3.72'} |

# %% [markdown]
# ### Non-negative Matrix Factorization

# %%
# %run experiments/nmf.py
# Out:
# ■ ■ ■ NMF ■ ■ ■
# ■ Performing random sampling on the dataset
# ■ Performing Grid Search
# ------------
# Parameters combination 1 of 4
# params:  {'n_epochs': 50, 'n_factors': 15}
# ------------
# Mean RMSE: 0.9769
# ------------
# ------------
# Parameters combination 2 of 4
# params:  {'n_epochs': 50, 'n_factors': 20}
# ------------
# Mean RMSE: 0.9813
# ------------
# ------------
# Parameters combination 3 of 4
# params:  {'n_epochs': 100, 'n_factors': 15}
# ------------
# Mean RMSE: 0.9758
# ------------
# ------------
# Parameters combination 4 of 4
# params:  {'n_epochs': 100, 'n_factors': 20}
# ------------
# Mean RMSE: 0.9739
# ------------
# ■ Grid Search summary
# |     RMSE |   n_epochs | params                             |
# |----------+------------+------------------------------------|
# | 0.97393  |        100 | {'n_epochs': 100, 'n_factors': 20} |
# | 0.975778 |        100 | {'n_epochs': 100, 'n_factors': 15} |
# | 0.976946 |         50 | {'n_epochs': 50, 'n_factors': 15}  |
# | 0.981349 |         50 | {'n_epochs': 50, 'n_factors': 20}  |
# ■ Algorithm properties
# surprise.prediction_algorithms.matrix_factorization.NMF at 0x7f95feae8828 (
#     biased = False,
#     bsl_options = {},
#     init_high = 1,
#     init_low = 0,
#     lr_bi = 0.005,
#     ...,
#     reg_pu = 0.06,
#     reg_qi = 0.06,
#     sim_options = {'user_based': True},
#     verbose = False
# )
# ■ Training using trainset
# Processing epoch 0
# Processing epoch 1
# Processing epoch 2
# Processing epoch 3
# Processing epoch 4
# Processing epoch 5
# Processing epoch 6
# Processing epoch 7
# Processing epoch 8
# Processing epoch 9
# Processing epoch 10
# Processing epoch 11
# Processing epoch 12
# Processing epoch 13
# Processing epoch 14
# Processing epoch 15
# Processing epoch 16
# Processing epoch 17
# Processing epoch 18
# Processing epoch 19
# Processing epoch 20
# Processing epoch 21
# Processing epoch 22
# Processing epoch 23
# Processing epoch 24
# Processing epoch 25
# Processing epoch 26
# Processing epoch 27
# Processing epoch 28
# Processing epoch 29
# Processing epoch 30
# Processing epoch 31
# Processing epoch 32
# Processing epoch 33
# Processing epoch 34
# Processing epoch 35
# Processing epoch 36
# Processing epoch 37
# Processing epoch 38
# Processing epoch 39
# Processing epoch 40
# Processing epoch 41
# Processing epoch 42
# Processing epoch 43
# Processing epoch 44
# Processing epoch 45
# Processing epoch 46
# Processing epoch 47
# Processing epoch 48
# Processing epoch 49
# Processing epoch 50
# Processing epoch 51
# Processing epoch 52
# Processing epoch 53
# Processing epoch 54
# Processing epoch 55
# Processing epoch 56
# Processing epoch 57
# Processing epoch 58
# Processing epoch 59
# Processing epoch 60
# Processing epoch 61
# Processing epoch 62
# Processing epoch 63
# Processing epoch 64
# Processing epoch 65
# Processing epoch 66
# Processing epoch 67
# Processing epoch 68
# Processing epoch 69
# Processing epoch 70
# Processing epoch 71
# Processing epoch 72
# Processing epoch 73
# Processing epoch 74
# Processing epoch 75
# Processing epoch 76
# Processing epoch 77
# Processing epoch 78
# Processing epoch 79
# Processing epoch 80
# Processing epoch 81
# Processing epoch 82
# Processing epoch 83
# Processing epoch 84
# Processing epoch 85
# Processing epoch 86
# Processing epoch 87
# Processing epoch 88
# Processing epoch 89
# Processing epoch 90
# Processing epoch 91
# Processing epoch 92
# Processing epoch 93
# Processing epoch 94
# Processing epoch 95
# Processing epoch 96
# Processing epoch 97
# Processing epoch 98
# Processing epoch 99
# ■ Evaluating using testset
# RMSE: 0.9578
# ■ Using the best estimator on the full dataset
# Processing epoch 0
# Processing epoch 1
# Processing epoch 2
# Processing epoch 3
# Processing epoch 4
# Processing epoch 5
# Processing epoch 6
# Processing epoch 7
# Processing epoch 8
# Processing epoch 9
# Processing epoch 10
# Processing epoch 11
# Processing epoch 12
# Processing epoch 13
# Processing epoch 14
# Processing epoch 15
# Processing epoch 16
# Processing epoch 17
# Processing epoch 18
# Processing epoch 19
# Processing epoch 20
# Processing epoch 21
# Processing epoch 22
# Processing epoch 23
# Processing epoch 24
# Processing epoch 25
# Processing epoch 26
# Processing epoch 27
# Processing epoch 28
# Processing epoch 29
# Processing epoch 30
# Processing epoch 31
# Processing epoch 32
# Processing epoch 33
# Processing epoch 34
# Processing epoch 35
# Processing epoch 36
# Processing epoch 37
# Processing epoch 38
# Processing epoch 39
# Processing epoch 40
# Processing epoch 41
# Processing epoch 42
# Processing epoch 43
# Processing epoch 44
# Processing epoch 45
# Processing epoch 46
# Processing epoch 47
# Processing epoch 48
# Processing epoch 49
# Processing epoch 50
# Processing epoch 51
# Processing epoch 52
# Processing epoch 53
# Processing epoch 54
# Processing epoch 55
# Processing epoch 56
# Processing epoch 57
# Processing epoch 58
# Processing epoch 59
# Processing epoch 60
# Processing epoch 61
# Processing epoch 62
# Processing epoch 63
# Processing epoch 64
# Processing epoch 65
# Processing epoch 66
# Processing epoch 67
# Processing epoch 68
# Processing epoch 69
# Processing epoch 70
# Processing epoch 71
# Processing epoch 72
# Processing epoch 73
# Processing epoch 74
# Processing epoch 75
# Processing epoch 76
# Processing epoch 77
# Processing epoch 78
# Processing epoch 79
# Processing epoch 80
# Processing epoch 81
# Processing epoch 82
# Processing epoch 83
# Processing epoch 84
# Processing epoch 85
# Processing epoch 86
# Processing epoch 87
# Processing epoch 88
# Processing epoch 89
# Processing epoch 90
# Processing epoch 91
# Processing epoch 92
# Processing epoch 93
# Processing epoch 94
# Processing epoch 95
# Processing epoch 96
# Processing epoch 97
# Processing epoch 98
# Processing epoch 99
# ■ Saving the trained model
# The dump has been saved as file /home/vinhnguyen/code/recommender/experiments/saved/nmf
# ■ Accuracy scores
# MAE:  0.8230
# RMSE: 1.0460
# ■ Precision and Recall
# |           |         1 |          2 |          3 |
# |-----------+-----------+------------+------------|
# | Precision | 1         | 1          | 1          |
# | Recall    | 0.0069541 | 0.00622665 | 0.00621118 |
# ■ Time elapsed: 0:01:19
# ■ Recommendations:
# | 1                              | 2                              | 3                              |
# |--------------------------------+--------------------------------+--------------------------------|
# | {'iid': '958', 'est': '5.00'}  | {'iid': '50', 'est': '5.00'}   | {'iid': '902', 'est': '4.92'}  |
# | {'iid': '1449', 'est': '5.00'} | {'iid': '963', 'est': '5.00'}  | {'iid': '1536', 'est': '4.90'} |
# | {'iid': '1463', 'est': '5.00'} | {'iid': '958', 'est': '5.00'}  | {'iid': '558', 'est': '4.86'}  |
# | {'iid': '408', 'est': '4.94'}  | {'iid': '1473', 'est': '5.00'} | {'iid': '694', 'est': '4.86'}  |
# | {'iid': '1664', 'est': '4.90'} | {'iid': '1512', 'est': '5.00'} | {'iid': '1367', 'est': '4.85'} |
# | {'iid': '180', 'est': '4.88'}  | {'iid': '1656', 'est': '5.00'} | {'iid': '838', 'est': '4.71'}  |
# | {'iid': '512', 'est': '4.88'}  | {'iid': '1449', 'est': '4.99'} | {'iid': '913', 'est': '4.65'}  |
# | {'iid': '1240', 'est': '4.87'} | {'iid': '64', 'est': '4.97'}   | {'iid': '718', 'est': '4.63'}  |
# | {'iid': '1122', 'est': '4.86'} | {'iid': '1405', 'est': '4.96'} | {'iid': '1171', 'est': '4.60'} |
# | {'iid': '516', 'est': '4.85'}  | {'iid': '516', 'est': '4.95'}  | {'iid': '1143', 'est': '4.59'} |

# %% [markdown]
# ### SlopeOne

# %%
# %run experiments/slope_one.py
# Out:
# ■ ■ ■ SlopeOne ■ ■ ■
# ■ Performing random sampling on the dataset
# ■ Training using trainset
# ■ Evaluating using testset
# RMSE: 0.9399
# ■ Using the best estimator on the full dataset
# ■ Saving the trained model
# The dump has been saved as file /home/vinhnguyen/code/recommender/experiments/saved/slope_one
# ■ Accuracy scores
# MAE:  0.7466
# RMSE: 0.9471
# ■ Precision and Recall
# |           |          1 |          2 |          3 |
# |-----------+------------+------------+------------|
# | Precision | 1          | 1          | 1          |
# | Recall    | 0.00701262 | 0.00626959 | 0.00621118 |
# ■ Time elapsed: 0:03:00
# ■ Recommendations:
# | 1                              | 2                              | 3                              |
# |--------------------------------+--------------------------------+--------------------------------|
# | {'iid': '1536', 'est': '5.00'} | {'iid': '1467', 'est': '5.00'} | {'iid': '814', 'est': '5.00'}  |
# | {'iid': '1293', 'est': '5.00'} | {'iid': '1536', 'est': '5.00'} | {'iid': '868', 'est': '5.00'}  |
# | {'iid': '1463', 'est': '5.00'} | {'iid': '1293', 'est': '5.00'} | {'iid': '1130', 'est': '5.00'} |
# | {'iid': '1599', 'est': '5.00'} | {'iid': '1599', 'est': '5.00'} | {'iid': '851', 'est': '4.95'}  |
# | {'iid': '851', 'est': '5.00'}  | {'iid': '851', 'est': '5.00'}  | {'iid': '848', 'est': '4.52'}  |
# | {'iid': '814', 'est': '5.00'}  | {'iid': '814', 'est': '5.00'}  | {'iid': '1449', 'est': '4.44'} |
# | {'iid': '1500', 'est': '5.00'} | {'iid': '1500', 'est': '5.00'} | {'iid': '1500', 'est': '4.44'} |
# | {'iid': '1467', 'est': '4.95'} | {'iid': '1656', 'est': '4.77'} | {'iid': '1593', 'est': '4.42'} |
# | {'iid': '1449', 'est': '4.89'} | {'iid': '1449', 'est': '4.75'} | {'iid': '835', 'est': '4.36'}  |
# | {'iid': '1642', 'est': '4.77'} | {'iid': '1189', 'est': '4.73'} | {'iid': '1536', 'est': '4.26'} |

# %% [markdown]
# ### SVD

# %%
# %run experiments/svd.py
# Out:
# ■ ■ ■ SVD ■ ■ ■
# ■ Performing random sampling on the dataset
# ■ Performing Grid Search
# ------------
# Parameters combination 1 of 4
# params:  {'reg_all': 0.01, 'n_factors': 100}
# ------------
# Mean RMSE: 0.9513
# ------------
# ------------
# Parameters combination 2 of 4
# params:  {'reg_all': 0.01, 'n_factors': 150}
# ------------
# Mean RMSE: 0.9557
# ------------
# ------------
# Parameters combination 3 of 4
# params:  {'reg_all': 0.02, 'n_factors': 100}
# ------------
# Mean RMSE: 0.9469
# ------------
# ------------
# Parameters combination 4 of 4
# params:  {'reg_all': 0.02, 'n_factors': 150}
# ------------
# Mean RMSE: 0.9477
# ------------
# ■ Grid Search summary
# |     RMSE | params                              |   reg_all |
# |----------+-------------------------------------+-----------|
# | 0.946914 | {'reg_all': 0.02, 'n_factors': 100} |      0.02 |
# | 0.947747 | {'reg_all': 0.02, 'n_factors': 150} |      0.02 |
# | 0.951329 | {'reg_all': 0.01, 'n_factors': 100} |      0.01 |
# | 0.955665 | {'reg_all': 0.01, 'n_factors': 150} |      0.01 |
# ■ Algorithm properties
# surprise.prediction_algorithms.matrix_factorization.SVD at 0x7f96038a3048 (
#     biased = True,
#     bsl_options = {},
#     init_mean = 0,
#     init_std_dev = 0.1,
#     lr_bi = 0.005,
#     ...,
#     reg_pu = 0.02,
#     reg_qi = 0.02,
#     sim_options = {'user_based': True},
#     verbose = False
# )
# ■ Training using trainset
# Processing epoch 0
# Processing epoch 1
# Processing epoch 2
# Processing epoch 3
# Processing epoch 4
# Processing epoch 5
# Processing epoch 6
# Processing epoch 7
# Processing epoch 8
# Processing epoch 9
# Processing epoch 10
# Processing epoch 11
# Processing epoch 12
# Processing epoch 13
# Processing epoch 14
# Processing epoch 15
# Processing epoch 16
# Processing epoch 17
# Processing epoch 18
# Processing epoch 19
# ■ Evaluating using testset
# RMSE: 0.9416
# ■ Using the best estimator on the full dataset
# Processing epoch 0
# Processing epoch 1
# Processing epoch 2
# Processing epoch 3
# Processing epoch 4
# Processing epoch 5
# Processing epoch 6
# Processing epoch 7
# Processing epoch 8
# Processing epoch 9
# Processing epoch 10
# Processing epoch 11
# Processing epoch 12
# Processing epoch 13
# Processing epoch 14
# Processing epoch 15
# Processing epoch 16
# Processing epoch 17
# Processing epoch 18
# Processing epoch 19
# ■ Saving the trained model
# The dump has been saved as file /home/vinhnguyen/code/recommender/experiments/saved/svd
# ■ Accuracy scores
# MAE:  0.4662
# RMSE: 0.5934
# ■ Precision and Recall
# |           |          1 |         2 |          3 |
# |-----------+------------+-----------+------------|
# | Precision | 1          | 1         | 1          |
# | Recall    | 0.00701754 | 0.0062422 | 0.00620732 |
# ■ Time elapsed: 0:01:26
# ■ Recommendations:
# | 1                             | 2                             | 3                             |
# |-------------------------------+-------------------------------+-------------------------------|
# | {'iid': '408', 'est': '5.00'} | {'iid': '603', 'est': '4.66'} | {'iid': '127', 'est': '4.29'} |
# | {'iid': '12', 'est': '4.80'}  | {'iid': '515', 'est': '4.64'} | {'iid': '178', 'est': '4.29'} |
# | {'iid': '513', 'est': '4.66'} | {'iid': '408', 'est': '4.63'} | {'iid': '483', 'est': '4.28'} |
# | {'iid': '709', 'est': '4.65'} | {'iid': '191', 'est': '4.60'} | {'iid': '511', 'est': '4.18'} |
# | {'iid': '483', 'est': '4.65'} | {'iid': '647', 'est': '4.56'} | {'iid': '174', 'est': '4.17'} |
# | {'iid': '856', 'est': '4.56'} | {'iid': '511', 'est': '4.54'} | {'iid': '172', 'est': '4.16'} |
# | {'iid': '664', 'est': '4.52'} | {'iid': '483', 'est': '4.53'} | {'iid': '12', 'est': '4.12'}  |
# | {'iid': '275', 'est': '4.51'} | {'iid': '89', 'est': '4.51'}  | {'iid': '50', 'est': '4.11'}  |
# | {'iid': '484', 'est': '4.49'} | {'iid': '657', 'est': '4.50'} | {'iid': '603', 'est': '4.11'} |
# | {'iid': '641', 'est': '4.49'} | {'iid': '169', 'est': '4.49'} | {'iid': '480', 'est': '4.10'} |

# %% [markdown]
# ### SVD++

# %%
# %run experiments/svdpp.py
# Out:
# ■ ■ ■ SVDpp ■ ■ ■
# ■ Performing random sampling on the dataset
# ■ Performing Grid Search
# ------------
# Parameters combination 1 of 4
# params:  {'n_epochs': 10, 'reg_all': 0.01}
# ------------
# Mean RMSE: 0.9408
# ------------
# ------------
# Parameters combination 2 of 4
# params:  {'n_epochs': 10, 'reg_all': 0.02}
# ------------
# Mean RMSE: 0.9474
# ------------
# ------------
# Parameters combination 3 of 4
# params:  {'n_epochs': 20, 'reg_all': 0.01}
# ------------
# Mean RMSE: 0.9420
# ------------
# ------------
# Parameters combination 4 of 4
# params:  {'n_epochs': 20, 'reg_all': 0.02}
# ------------
# Mean RMSE: 0.9370
# ------------
# ■ Grid Search summary
# |     RMSE |   n_epochs | params                            |
# |----------+------------+-----------------------------------|
# | 0.937002 |         20 | {'n_epochs': 20, 'reg_all': 0.02} |
# | 0.940843 |         10 | {'n_epochs': 10, 'reg_all': 0.01} |
# | 0.941963 |         20 | {'n_epochs': 20, 'reg_all': 0.01} |
# | 0.947395 |         10 | {'n_epochs': 10, 'reg_all': 0.02} |
# ■ Algorithm properties
# surprise.prediction_algorithms.matrix_factorization.SVDpp at 0x7f95e890fb00 (
#     bsl_options = {},
#     init_mean = 0,
#     init_std_dev = 0.1,
#     lr_bi = 0.007,
#     lr_bu = 0.007,
#     ...,
#     reg_qi = 0.02,
#     reg_yj = 0.02,
#     sim_options = {'user_based': True},
#     verbose = False
# )
# ■ Training using trainset
#  processing epoch 0
#  processing epoch 1
#  processing epoch 2
#  processing epoch 3
#  processing epoch 4
#  processing epoch 5
#  processing epoch 6
#  processing epoch 7
#  processing epoch 8
#  processing epoch 9
#  processing epoch 10
#  processing epoch 11
#  processing epoch 12
#  processing epoch 13
#  processing epoch 14
#  processing epoch 15
#  processing epoch 16
#  processing epoch 17
#  processing epoch 18
#  processing epoch 19
# ■ Evaluating using testset
# RMSE: 0.9132
# ■ Using the best estimator on the full dataset
#  processing epoch 0
#  processing epoch 1
#  processing epoch 2
#  processing epoch 3
#  processing epoch 4
#  processing epoch 5
#  processing epoch 6
#  processing epoch 7
#  processing epoch 8
#  processing epoch 9
#  processing epoch 10
#  processing epoch 11
#  processing epoch 12
#  processing epoch 13
#  processing epoch 14
#  processing epoch 15
#  processing epoch 16
#  processing epoch 17
#  processing epoch 18
#  processing epoch 19
# ■ Saving the trained model
# The dump has been saved as file /home/vinhnguyen/code/recommender/experiments/saved/svdpp
# ■ Accuracy scores
# MAE:  0.4978
# RMSE: 0.6330
# ■ Precision and Recall
# |           |          1 |         2 |         3 |
# |-----------+------------+-----------+-----------|
# | Precision | 1          | 1         | 1         |
# | Recall    | 0.00702741 | 0.0062422 | 0.0062461 |
# ■ Time elapsed: 0:10:21
# ■ Recommendations:
# | 1                             | 2                             | 3                             |
# |-------------------------------+-------------------------------+-------------------------------|
# | {'iid': '276', 'est': '5.00'} | {'iid': '408', 'est': '4.78'} | {'iid': '357', 'est': '4.28'} |
# | {'iid': '50', 'est': '5.00'}  | {'iid': '357', 'est': '4.76'} | {'iid': '127', 'est': '4.25'} |
# | {'iid': '268', 'est': '5.00'} | {'iid': '169', 'est': '4.71'} | {'iid': '408', 'est': '4.24'} |
# | {'iid': '750', 'est': '5.00'} | {'iid': '12', 'est': '4.71'}  | {'iid': '136', 'est': '4.20'} |
# | {'iid': '511', 'est': '5.00'} | {'iid': '64', 'est': '4.70'}  | {'iid': '483', 'est': '4.19'} |
# | {'iid': '285', 'est': '5.00'} | {'iid': '180', 'est': '4.70'} | {'iid': '180', 'est': '4.17'} |
# | {'iid': '302', 'est': '4.99'} | {'iid': '603', 'est': '4.69'} | {'iid': '474', 'est': '4.16'} |
# | {'iid': '474', 'est': '4.94'} | {'iid': '56', 'est': '4.67'}  | {'iid': '480', 'est': '4.15'} |
# | {'iid': '60', 'est': '4.94'}  | {'iid': '135', 'est': '4.67'} | {'iid': '12', 'est': '4.15'}  |
# | {'iid': '641', 'est': '4.93'} | {'iid': '483', 'est': '4.64'} | {'iid': '661', 'est': '4.10'} |

# %% [markdown]
# ### Visualizing the movie-lens dataset

# %%
import os
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt

def load_data_into_dataframe(path):
    if not os.path.exists(path):
        raise RuntimeError('Cannot find the given dataset!')
    df = pd.read_csv(path, sep='\t', names=['UserID', 'ItemID', 'Rating', 'Timestamp'])
    return df

path = os.path.expanduser('~/.surprise_data/ml-100k/ml-100k/u.data')
df = load_data_into_dataframe(path)

# %%
print(df.shape)
# Out:
# (100000, 4)

# %%
print(df.columns)
# Out:
# Index(['UserID', 'ItemID', 'Rating', 'Timestamp'], dtype='object')

# %%
print(df.head())
# Out:
#    UserID  ItemID  Rating  Timestamp
# 0     196     242       3  881250949
# 1     186     302       3  891717742
# 2      22     377       1  878887116
# 3     244      51       2  880606923
# 4     166     346       1  886397596

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 4 columns):
# UserID       100000 non-null int64
# ItemID       100000 non-null int64
# Rating       100000 non-null int64
# Timestamp    100000 non-null int64
# dtypes: int64(4)
# memory usage: 3.1 MB
# None

# %%
print(df.describe())
# Out:
#              UserID         ItemID         Rating     Timestamp
# count  100000.00000  100000.000000  100000.000000  1.000000e+05
# mean      462.48475     425.530130       3.529860  8.835289e+08
# std       266.61442     330.798356       1.125674  5.343856e+06
# min         1.00000       1.000000       1.000000  8.747247e+08
# 25%       254.00000     175.000000       3.000000  8.794487e+08
# 50%       447.00000     322.000000       4.000000  8.828269e+08
# 75%       682.00000     631.000000       4.000000  8.882600e+08
# max       943.00000    1682.000000       5.000000  8.932866e+08

# %%
plt.hist(df['Rating'])
# Out:
# (array([  6110.,      0.,  11370.,      0.,      0.,  27145.,      0.,
#          34174.,      0.,  21201.]),
#  array([ 1. ,  1.4,  1.8,  2.2,  2.6,  3. ,  3.4,  3.8,  4.2,  4.6,  5. ]),
#  <a list of 10 Patch objects>)

# %%
df.groupby(['Rating'])['UserID'].count()
# Out:
# Rating
# 1     6110
# 2    11370
# 3    27145
# 4    34174
# 5    21201
# Name: UserID, dtype: int64

# %%
plt.hist(df.groupby(['ItemID'])['ItemID'].count())
# Out:
# (array([  1.14600000e+03,   2.49000000e+02,   1.39000000e+02,
#           6.70000000e+01,   3.80000000e+01,   2.40000000e+01,
#           7.00000000e+00,   5.00000000e+00,   6.00000000e+00,
#           1.00000000e+00]),
#  array([   1. ,   59.2,  117.4,  175.6,  233.8,  292. ,  350.2,  408.4,
#          466.6,  524.8,  583. ]),
#  <a list of 10 Patch objects>)
