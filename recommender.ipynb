# %%
import os
import sys

module = os.path.expanduser('~/code/recommender-notebook/rs')
if os.path.exists(module) and module not in sys.path:
    sys.path.append(module)

# %% [markdown]
# ### BaselineOnly

# %%
# %run experiments/baseline_only.py
# Out:
# ■ ■ ■ BaselineOnly ■ ■ ■
# ■ Performing random sampling on the dataset
# ■ Performing Grid Search
# ------------
# Parameters combination 1 of 2
# params:  {'bsl_options': {'method': 'als', 'n_epochs': 30}}
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# ------------
# Mean RMSE: 0.9492
# ------------
# ------------
# Parameters combination 2 of 2
# params:  {'bsl_options': {'learning_rate': 0.0007, 'method': 'sgd', 'n_epochs': 30}}
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# ------------
# Mean RMSE: 0.9651
# ------------
# ■ Grid Search completed. Here is the summary:
#        RMSE                                        bsl_options  \
# 0  0.949182                  {'method': 'als', 'n_epochs': 30}
# 1  0.965065  {'learning_rate': 0.0007, 'method': 'sgd', 'n_...
#
#                                               params                    scores
# 0  {'bsl_options': {'method': 'als', 'n_epochs': ...  {'RMSE': 0.949182105414}
# 1  {'bsl_options': {'learning_rate': 0.0007, 'met...  {'RMSE': 0.965064549606}
# ■ Algorithm properties:
# surprise.prediction_algorithms.baseline_only.BaselineOnly at 0x7fb9b8d132e8 (
#     bsl_options = {'method': 'als', 'n_epochs': 30},
#     sim_options = {'user_based': True},
#     verbose = True
# )
# ■ Training using trainset
# Estimating biases using als...
# ■ Evaluating using testset
# RMSE: 0.9389
# ■ Using the best estimator on full dataset
# ■ Saving the trained model
# The dump has been saved as file /home/vinhnguyen/code/recommender-notebook/experiments/trained_models/baseline_only
# ■ Accuracy scores:
# MAE:  0.3873
# RMSE: 0.4938
# ■ Time elapsed: 0:00:58
# ■ Recommendations:
# |    | 1                             | 2                             | 3                             |
# |----+-------------------------------+-------------------------------+-------------------------------|
# |  0 | {'est': '4.48', 'iid': '408'} | {'est': '4.54', 'iid': '408'} | {'est': '4.12', 'iid': '408'} |
# |  1 | {'est': '4.45', 'iid': '483'} | {'est': '4.51', 'iid': '483'} | {'est': '4.09', 'iid': '483'} |
# |  2 | {'est': '4.43', 'iid': '318'} | {'est': '4.50', 'iid': '318'} | {'est': '4.05', 'iid': '169'} |
# |  3 | {'est': '4.34', 'iid': '603'} | {'est': '4.47', 'iid': '64'}  | {'est': '4.04', 'iid': '64'}  |
# |  4 | {'est': '4.28', 'iid': '357'} | {'est': '4.47', 'iid': '169'} | {'est': '4.00', 'iid': '50'}  |
# |  5 | {'est': '4.28', 'iid': '480'} | {'est': '4.42', 'iid': '12'}  | {'est': '4.00', 'iid': '12'}  |
# |  6 | {'est': '4.25', 'iid': '474'} | {'est': '4.40', 'iid': '603'} | {'est': '3.98', 'iid': '603'} |
# |  7 | {'est': '4.25', 'iid': '479'} | {'est': '4.38', 'iid': '114'} | {'est': '3.96', 'iid': '114'} |
# |  8 | {'est': '4.23', 'iid': '427'} | {'est': '4.35', 'iid': '357'} | {'est': '3.93', 'iid': '98'}  |
# |  9 | {'est': '4.22', 'iid': '313'} | {'est': '4.35', 'iid': '98'}  | {'est': '3.92', 'iid': '174'} |

# %% [markdown]
# ### CoClustering

# %%
# %run experiments/co_clustering.py
# Out:
# ■ ■ ■ CoClustering ■ ■ ■
# ■ Performing random sampling on the dataset
# ■ Performing Grid Search
# ------------
# Parameters combination 1 of 8
# params:  {'n_cltr_u': 3, 'n_cltr_i': 3, 'n_epochs': 20}
# ------------
# Mean RMSE: 0.9738
# ------------
# ------------
# Parameters combination 2 of 8
# params:  {'n_cltr_u': 3, 'n_cltr_i': 3, 'n_epochs': 60}
# ------------
# Mean RMSE: 0.9738
# ------------
# ------------
# Parameters combination 3 of 8
# params:  {'n_cltr_u': 5, 'n_cltr_i': 3, 'n_epochs': 20}
# ------------
# Mean RMSE: 0.9749
# ------------
# ------------
# Parameters combination 4 of 8
# params:  {'n_cltr_u': 5, 'n_cltr_i': 3, 'n_epochs': 60}
# ------------
# Mean RMSE: 0.9776
# ------------
# ------------
# Parameters combination 5 of 8
# params:  {'n_cltr_u': 3, 'n_cltr_i': 5, 'n_epochs': 20}
# ------------
# Mean RMSE: 0.9763
# ------------
# ------------
# Parameters combination 6 of 8
# params:  {'n_cltr_u': 3, 'n_cltr_i': 5, 'n_epochs': 60}
# ------------
# Mean RMSE: 0.9779
# ------------
# ------------
# Parameters combination 7 of 8
# params:  {'n_cltr_u': 5, 'n_cltr_i': 5, 'n_epochs': 20}
# ------------
# Mean RMSE: 0.9847
# ------------
# ------------
# Parameters combination 8 of 8
# params:  {'n_cltr_u': 5, 'n_cltr_i': 5, 'n_epochs': 60}
# ------------
# Mean RMSE: 0.9815
# ------------
# ■ Grid Search completed. Here is the summary:
#        RMSE  n_cltr_u                                          params  \
# 1  0.973779         3  {'n_cltr_u': 3, 'n_cltr_i': 3, 'n_epochs': 60}
# 0  0.973804         3  {'n_cltr_u': 3, 'n_cltr_i': 3, 'n_epochs': 20}
# 2  0.974870         5  {'n_cltr_u': 5, 'n_cltr_i': 3, 'n_epochs': 20}
# 4  0.976329         3  {'n_cltr_u': 3, 'n_cltr_i': 5, 'n_epochs': 20}
# 3  0.977577         5  {'n_cltr_u': 5, 'n_cltr_i': 3, 'n_epochs': 60}
# 5  0.977941         3  {'n_cltr_u': 3, 'n_cltr_i': 5, 'n_epochs': 60}
# 7  0.981545         5  {'n_cltr_u': 5, 'n_cltr_i': 5, 'n_epochs': 60}
# 6  0.984733         5  {'n_cltr_u': 5, 'n_cltr_i': 5, 'n_epochs': 20}
#
#                      scores
# 1  {'RMSE': 0.973779010882}
# 0  {'RMSE': 0.973804157646}
# 2  {'RMSE': 0.974870459613}
# 4  {'RMSE': 0.976329105668}
# 3  {'RMSE': 0.977577471992}
# 5  {'RMSE': 0.977941286771}
# 7  {'RMSE': 0.981544671404}
# 6  {'RMSE': 0.984732907411}
# ■ Algorithm properties:
# surprise.prediction_algorithms.co_clustering.CoClustering at 0x7fb958427048 (
#     bsl_options = {},
#     n_cltr_i = 3,
#     n_cltr_u = 3,
#     n_epochs = 60,
#     sim_options = {'user_based': True},
#     verbose = True
# )
# ■ Training using trainset
# Processing epoch 0
# Processing epoch 1
# Processing epoch 2
# Processing epoch 3
# Processing epoch 4
# Processing epoch 5
# Processing epoch 6
# Processing epoch 7
# Processing epoch 8
# Processing epoch 9
# Processing epoch 10
# Processing epoch 11
# Processing epoch 12
# Processing epoch 13
# Processing epoch 14
# Processing epoch 15
# Processing epoch 16
# Processing epoch 17
# Processing epoch 18
# Processing epoch 19
# Processing epoch 20
# Processing epoch 21
# Processing epoch 22
# Processing epoch 23
# Processing epoch 24
# Processing epoch 25
# Processing epoch 26
# Processing epoch 27
# Processing epoch 28
# Processing epoch 29
# Processing epoch 30
# Processing epoch 31
# Processing epoch 32
# Processing epoch 33
# Processing epoch 34
# Processing epoch 35
# Processing epoch 36
# Processing epoch 37
# Processing epoch 38
# Processing epoch 39
# Processing epoch 40
# Processing epoch 41
# Processing epoch 42
# Processing epoch 43
# Processing epoch 44
# Processing epoch 45
# Processing epoch 46
# Processing epoch 47
# Processing epoch 48
# Processing epoch 49
# Processing epoch 50
# Processing epoch 51
# Processing epoch 52
# Processing epoch 53
# Processing epoch 54
# Processing epoch 55
# Processing epoch 56
# Processing epoch 57
# Processing epoch 58
# Processing epoch 59
# ■ Evaluating using testset
# RMSE: 0.9638
# ■ Using the best estimator on full dataset
# ■ Saving the trained model
# The dump has been saved as file /home/vinhnguyen/code/recommender-notebook/experiments/trained_models/co_clustering
# ■ Accuracy scores:
# MAE:  0.7618
# RMSE: 0.9797
# ■ Time elapsed: 0:00:51
# ■ Recommendations:
# |    | 1                              | 2                              | 3                              |
# |----+--------------------------------+--------------------------------+--------------------------------|
# |  0 | {'est': '5.00', 'iid': '1064'} | {'est': '5.00', 'iid': '1064'} | {'est': '4.38', 'iid': '1293'} |
# |  1 | {'est': '5.00', 'iid': '1293'} | {'est': '5.00', 'iid': '1293'} | {'est': '4.38', 'iid': '814'}  |
# |  2 | {'est': '5.00', 'iid': '1122'} | {'est': '5.00', 'iid': '1122'} | {'est': '4.15', 'iid': '1064'} |
# |  3 | {'est': '5.00', 'iid': '1189'} | {'est': '5.00', 'iid': '1189'} | {'est': '4.15', 'iid': '1122'} |
# |  4 | {'est': '5.00', 'iid': '1467'} | {'est': '5.00', 'iid': '1467'} | {'est': '4.15', 'iid': '1189'} |
# |  5 | {'est': '5.00', 'iid': '814'}  | {'est': '5.00', 'iid': '814'}  | {'est': '4.15', 'iid': '1467'} |
# |  6 | {'est': '5.00', 'iid': '1628'} | {'est': '5.00', 'iid': '1628'} | {'est': '4.15', 'iid': '1628'} |
# |  7 | {'est': '5.00', 'iid': '1594'} | {'est': '5.00', 'iid': '1594'} | {'est': '4.15', 'iid': '1594'} |
# |  8 | {'est': '5.00', 'iid': '1201'} | {'est': '5.00', 'iid': '1201'} | {'est': '4.15', 'iid': '1201'} |
# |  9 | {'est': '5.00', 'iid': '1536'} | {'est': '5.00', 'iid': '1536'} | {'est': '4.15', 'iid': '1536'} |

# %% [markdown]
# ### KNNBaseline

# %%
# %run experiments/knn_baseline.py
# Out:
# ■ ■ ■ KNNBaseline ■ ■ ■
# ■ Performing random sampling on the dataset
# ■ Performing Grid Search
# ------------
# Parameters combination 1 of 8
# params:  {'k': 20, 'bsl_options': {'method': 'als', 'n_epochs': 30}, 'sim_options': {'name': 'cosine'}}
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9499
# ------------
# ------------
# Parameters combination 2 of 8
# params:  {'k': 20, 'bsl_options': {'method': 'als', 'n_epochs': 30}, 'sim_options': {'name': 'pearson_baseline', 'shrinkage': 150}}
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9392
# ------------
# ------------
# Parameters combination 3 of 8
# params:  {'k': 20, 'bsl_options': {'learning_rate': 0.0007, 'method': 'sgd', 'n_epochs': 30}, 'sim_options': {'user_based': True, 'name': 'cosine'}}
# Estimating biases using sgd...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9558
# ------------
# ------------
# Parameters combination 4 of 8
# params:  {'k': 20, 'bsl_options': {'learning_rate': 0.0007, 'method': 'sgd', 'n_epochs': 30}, 'sim_options': {'user_based': True, 'name': 'pearson_baseline', 'shrinkage': 150}}
# Estimating biases using sgd...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9419
# ------------
# ------------
# Parameters combination 5 of 8
# params:  {'k': 40, 'bsl_options': {'method': 'als', 'n_epochs': 30}, 'sim_options': {'user_based': True, 'name': 'cosine'}}
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9434
# ------------
# ------------
# Parameters combination 6 of 8
# params:  {'k': 40, 'bsl_options': {'method': 'als', 'n_epochs': 30}, 'sim_options': {'user_based': True, 'name': 'pearson_baseline', 'shrinkage': 150}}
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9364
# ------------
# ------------
# Parameters combination 7 of 8
# params:  {'k': 40, 'bsl_options': {'learning_rate': 0.0007, 'method': 'sgd', 'n_epochs': 30}, 'sim_options': {'user_based': True, 'name': 'cosine'}}
# Estimating biases using sgd...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9490
# ------------
# ------------
# Parameters combination 8 of 8
# params:  {'k': 40, 'bsl_options': {'learning_rate': 0.0007, 'method': 'sgd', 'n_epochs': 30}, 'sim_options': {'user_based': True, 'name': 'pearson_baseline', 'shrinkage': 150}}
# Estimating biases using sgd...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9389
# ------------
# ■ Grid Search completed. Here is the summary:
#        RMSE   k                                             params  \
# 5  0.936362  40  {'k': 40, 'bsl_options': {'method': 'als', 'n_...
# 7  0.938853  40  {'k': 40, 'bsl_options': {'learning_rate': 0.0...
# 1  0.939179  20  {'k': 20, 'bsl_options': {'method': 'als', 'n_...
# 3  0.941932  20  {'k': 20, 'bsl_options': {'learning_rate': 0.0...
# 4  0.943361  40  {'k': 40, 'bsl_options': {'method': 'als', 'n_...
# 6  0.948965  40  {'k': 40, 'bsl_options': {'learning_rate': 0.0...
# 0  0.949915  20  {'k': 20, 'bsl_options': {'method': 'als', 'n_...
# 2  0.955845  20  {'k': 20, 'bsl_options': {'learning_rate': 0.0...
#
#                      scores
# 5  {'RMSE': 0.936362275251}
# 7  {'RMSE': 0.938853313483}
# 1  {'RMSE': 0.939179443624}
# 3  {'RMSE': 0.941932288736}
# 4  {'RMSE': 0.943361320341}
# 6  {'RMSE': 0.948965115099}
# 0  {'RMSE': 0.949914958237}
# 2  {'RMSE': 0.955844576094}
# ■ Algorithm properties:
# surprise.prediction_algorithms.knns.KNNBaseline at 0x7fb963451390 (
#     bsl_options = {'method': 'als', 'n_epochs': 30},
#     k = 40,
#     min_k = 1,
#     sim_options = {'user_based': True, 'name': 'pearson_baseline', 'shrinkage': 150},
#     verbose = True
# )
# ■ Training using trainset
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# ■ Evaluating using testset
# RMSE: 0.9145
# ■ Using the best estimator on full dataset
# ■ Saving the trained model
# The dump has been saved as file /home/vinhnguyen/code/recommender-notebook/experiments/trained_models/knn_baseline
# ■ Accuracy scores:
# MAE:  0.6325
# RMSE: 0.8183
# ■ Time elapsed: 0:03:10
# ■ Recommendations:
# |    | 1                              | 2                              | 3                              |
# |----+--------------------------------+--------------------------------+--------------------------------|
# |  0 | {'est': '5.00', 'iid': '851'}  | {'est': '5.00', 'iid': '1463'} | {'est': '5.00', 'iid': '1449'} |
# |  1 | {'est': '5.00', 'iid': '1449'} | {'est': '5.00', 'iid': '1131'} | {'est': '5.00', 'iid': '1643'} |
# |  2 | {'est': '5.00', 'iid': '909'}  | {'est': '5.00', 'iid': '1479'} | {'est': '5.00', 'iid': '1536'} |
# |  3 | {'est': '5.00', 'iid': '1589'} | {'est': '5.00', 'iid': '838'}  | {'est': '4.89', 'iid': '1591'} |
# |  4 | {'est': '5.00', 'iid': '1192'} | {'est': '5.00', 'iid': '1600'} | {'est': '4.80', 'iid': '1347'} |
# |  5 | {'est': '5.00', 'iid': '848'}  | {'est': '5.00', 'iid': '1554'} | {'est': '4.78', 'iid': '1306'} |
# |  6 | {'est': '5.00', 'iid': '1367'} | {'est': '5.00', 'iid': '1628'} | {'est': '4.71', 'iid': '1628'} |
# |  7 | {'est': '5.00', 'iid': '1388'} | {'est': '5.00', 'iid': '1491'} | {'est': '4.69', 'iid': '1491'} |
# |  8 | {'est': '5.00', 'iid': '1628'} | {'est': '5.00', 'iid': '1629'} | {'est': '4.69', 'iid': '1500'} |
# |  9 | {'est': '5.00', 'iid': '1467'} | {'est': '5.00', 'iid': '1639'} | {'est': '4.67', 'iid': '1653'} |

# %% [markdown]
# ### KNNBasic

# %%
# %run experiments/knn_basic.py
# Out:
# ■ ■ ■ KNNBasic ■ ■ ■
# ■ Performing random sampling on the dataset
# ■ Performing Grid Search
# ------------
# Parameters combination 1 of 10
# params:  {'k': 20, 'sim_options': {'name': 'msd'}}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9901
# ------------
# ------------
# Parameters combination 2 of 10
# params:  {'k': 20, 'sim_options': {'name': 'cosine'}}
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 1.0304
# ------------
# ------------
# Parameters combination 3 of 10
# params:  {'k': 20, 'sim_options': {'name': 'pearson'}}
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 1.0274
# ------------
# ------------
# Parameters combination 4 of 10
# params:  {'k': 20, 'sim_options': {'name': 'pearson_baseline'}}
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 1.0155
# ------------
# ------------
# Parameters combination 5 of 10
# params:  {'k': 20, 'sim_options': {'name': 'pearson_baseline', 'shrinkage': 150}}
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 1.0156
# ------------
# ------------
# Parameters combination 6 of 10
# params:  {'k': 40, 'sim_options': {'user_based': True, 'name': 'msd'}}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9905
# ------------
# ------------
# Parameters combination 7 of 10
# params:  {'k': 40, 'sim_options': {'user_based': True, 'name': 'cosine'}}
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 1.0218
# ------------
# ------------
# Parameters combination 8 of 10
# params:  {'k': 40, 'sim_options': {'user_based': True, 'name': 'pearson'}}
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 1.0201
# ------------
# ------------
# Parameters combination 9 of 10
# params:  {'k': 40, 'sim_options': {'user_based': True, 'name': 'pearson_baseline'}}
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 1.0126
# ------------
# ------------
# Parameters combination 10 of 10
# params:  {'k': 40, 'sim_options': {'user_based': True, 'name': 'pearson_baseline', 'shrinkage': 150}}
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 1.0126
# ------------
# ■ Grid Search completed. Here is the summary:
#        RMSE   k                                             params  \
# 0  0.990136  20  {'k': 20, 'sim_options': {'user_based': True, ...
# 5  0.990455  40  {'k': 40, 'sim_options': {'user_based': True, ...
# 8  1.012572  40  {'k': 40, 'sim_options': {'user_based': True, ...
# 9  1.012606  40  {'k': 40, 'sim_options': {'user_based': True, ...
# 3  1.015490  20  {'k': 20, 'sim_options': {'user_based': True, ...
# 4  1.015574  20  {'k': 20, 'sim_options': {'user_based': True, ...
# 7  1.020111  40  {'k': 40, 'sim_options': {'user_based': True, ...
# 6  1.021838  40  {'k': 40, 'sim_options': {'user_based': True, ...
# 2  1.027407  20  {'k': 20, 'sim_options': {'user_based': True, ...
# 1  1.030363  20  {'k': 20, 'sim_options': {'user_based': True, ...
#
#                     scores
# 0  {'RMSE': 0.99013635487}
# 5   {'RMSE': 0.9904545874}
# 8  {'RMSE': 1.01257244204}
# 9   {'RMSE': 1.0126059403}
# 3  {'RMSE': 1.01548984954}
# 4  {'RMSE': 1.01557396371}
# 7  {'RMSE': 1.02011103094}
# 6  {'RMSE': 1.02183831618}
# 2  {'RMSE': 1.02740661198}
# 1  {'RMSE': 1.03036273872}
# ■ Algorithm properties:
# surprise.prediction_algorithms.knns.KNNBasic at 0x7fb9932a2518 (
#     bsl_options = {},
#     k = 20,
#     min_k = 1,
#     sim_options = {'user_based': True, 'name': 'msd'},
#     verbose = True
# )
# ■ Training using trainset
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ■ Evaluating using testset
# RMSE: 0.9766
# ■ Using the best estimator on full dataset
# ■ Saving the trained model
# The dump has been saved as file /home/vinhnguyen/code/recommender-notebook/experiments/trained_models/knn_basic
# ■ Accuracy scores:
# MAE:  0.6879
# RMSE: 0.9084
# ■ Time elapsed: 0:02:27
# ■ Recommendations:
# |    | 1                              | 2                              | 3                              |
# |----+--------------------------------+--------------------------------+--------------------------------|
# |  0 | {'est': '5.00', 'iid': '1293'} | {'est': '5.00', 'iid': '1293'} | {'est': '5.00', 'iid': '1293'} |
# |  1 | {'est': '5.00', 'iid': '1201'} | {'est': '5.00', 'iid': '1201'} | {'est': '5.00', 'iid': '1201'} |
# |  2 | {'est': '5.00', 'iid': '1189'} | {'est': '5.00', 'iid': '1189'} | {'est': '5.00', 'iid': '1189'} |
# |  3 | {'est': '5.00', 'iid': '814'}  | {'est': '5.00', 'iid': '814'}  | {'est': '5.00', 'iid': '814'}  |
# |  4 | {'est': '5.00', 'iid': '1275'} | {'est': '5.00', 'iid': '1275'} | {'est': '5.00', 'iid': '1275'} |
# |  5 | {'est': '5.00', 'iid': '1536'} | {'est': '5.00', 'iid': '1536'} | {'est': '5.00', 'iid': '1536'} |
# |  6 | {'est': '5.00', 'iid': '1617'} | {'est': '5.00', 'iid': '1617'} | {'est': '5.00', 'iid': '1617'} |
# |  7 | {'est': '5.00', 'iid': '1500'} | {'est': '5.00', 'iid': '1500'} | {'est': '5.00', 'iid': '1500'} |
# |  8 | {'est': '5.00', 'iid': '1599'} | {'est': '5.00', 'iid': '1599'} | {'est': '5.00', 'iid': '1599'} |
# |  9 | {'est': '5.00', 'iid': '1472'} | {'est': '5.00', 'iid': '1472'} | {'est': '5.00', 'iid': '1122'} |

# %% [markdown]
# ### KNNWithMeans

# %%
# %run experiments/knn_with_means.py
# Out:
# ■ ■ ■ KNNWithMeans ■ ■ ■
# ■ Performing random sampling on the dataset
# ■ Performing Grid Search
# ------------
# Parameters combination 1 of 10
# params:  {'k': 20, 'sim_options': {'name': 'msd'}}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9670
# ------------
# ------------
# Parameters combination 2 of 10
# params:  {'k': 20, 'sim_options': {'name': 'cosine'}}
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9732
# ------------
# ------------
# Parameters combination 3 of 10
# params:  {'k': 20, 'sim_options': {'name': 'pearson'}}
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9677
# ------------
# ------------
# Parameters combination 4 of 10
# params:  {'k': 20, 'sim_options': {'name': 'pearson_baseline'}}
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9534
# ------------
# ------------
# Parameters combination 5 of 10
# params:  {'k': 20, 'sim_options': {'name': 'pearson_baseline', 'shrinkage': 150}}
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9533
# ------------
# ------------
# Parameters combination 6 of 10
# params:  {'k': 40, 'sim_options': {'user_based': True, 'name': 'msd'}}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9597
# ------------
# ------------
# Parameters combination 7 of 10
# params:  {'k': 40, 'sim_options': {'user_based': True, 'name': 'cosine'}}
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9641
# ------------
# ------------
# Parameters combination 8 of 10
# params:  {'k': 40, 'sim_options': {'user_based': True, 'name': 'pearson'}}
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9605
# ------------
# ------------
# Parameters combination 9 of 10
# params:  {'k': 40, 'sim_options': {'user_based': True, 'name': 'pearson_baseline'}}
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9518
# ------------
# ------------
# Parameters combination 10 of 10
# params:  {'k': 40, 'sim_options': {'user_based': True, 'name': 'pearson_baseline', 'shrinkage': 150}}
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9517
# ------------
# ■ Grid Search completed. Here is the summary:
#        RMSE   k                                             params  \
# 9  0.951718  40  {'k': 40, 'sim_options': {'user_based': True, ...
# 8  0.951849  40  {'k': 40, 'sim_options': {'user_based': True, ...
# 4  0.953325  20  {'k': 20, 'sim_options': {'user_based': True, ...
# 3  0.953449  20  {'k': 20, 'sim_options': {'user_based': True, ...
# 5  0.959712  40  {'k': 40, 'sim_options': {'user_based': True, ...
# 7  0.960515  40  {'k': 40, 'sim_options': {'user_based': True, ...
# 6  0.964072  40  {'k': 40, 'sim_options': {'user_based': True, ...
# 0  0.966990  20  {'k': 20, 'sim_options': {'user_based': True, ...
# 2  0.967743  20  {'k': 20, 'sim_options': {'user_based': True, ...
# 1  0.973214  20  {'k': 20, 'sim_options': {'user_based': True, ...
#
#                      scores
# 9  {'RMSE': 0.951718224952}
# 8   {'RMSE': 0.95184862258}
# 4  {'RMSE': 0.953324794157}
# 3  {'RMSE': 0.953448820041}
# 5  {'RMSE': 0.959712389627}
# 7  {'RMSE': 0.960515495461}
# 6  {'RMSE': 0.964071979023}
# 0  {'RMSE': 0.966990297526}
# 2  {'RMSE': 0.967743022446}
# 1  {'RMSE': 0.973214252853}
# ■ Algorithm properties:
# surprise.prediction_algorithms.knns.KNNWithMeans at 0x7fb96f5d4c50 (
#     bsl_options = {},
#     k = 40,
#     min_k = 1,
#     sim_options = {'user_based': True, 'name': 'pearson_baseline', 'shrinkage': 150},
#     verbose = True
# )
# ■ Training using trainset
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# ■ Evaluating using testset
# RMSE: 0.9361
# ■ Using the best estimator on full dataset
# ■ Saving the trained model
# The dump has been saved as file /home/vinhnguyen/code/recommender-notebook/experiments/trained_models/knn_with_means
# ■ Accuracy scores:
# MAE:  0.6401
# RMSE: 0.8248
# ■ Time elapsed: 0:02:39
# ■ Recommendations:
# |    | 1                              | 2                              | 3                              |
# |----+--------------------------------+--------------------------------+--------------------------------|
# |  0 | {'est': '5.00', 'iid': '1629'} | {'est': '5.00', 'iid': '1467'} | {'est': '4.89', 'iid': '1643'} |
# |  1 | {'est': '5.00', 'iid': '1589'} | {'est': '5.00', 'iid': '1463'} | {'est': '4.78', 'iid': '1591'} |
# |  2 | {'est': '5.00', 'iid': '1467'} | {'est': '5.00', 'iid': '868'}  | {'est': '4.71', 'iid': '1368'} |
# |  3 | {'est': '5.00', 'iid': '1449'} | {'est': '5.00', 'iid': '1512'} | {'est': '4.60', 'iid': '1491'} |
# |  4 | {'est': '5.00', 'iid': '868'}  | {'est': '5.00', 'iid': '814'}  | {'est': '4.36', 'iid': '1306'} |
# |  5 | {'est': '5.00', 'iid': '814'}  | {'est': '5.00', 'iid': '1085'} | {'est': '4.29', 'iid': '1463'} |
# |  6 | {'est': '5.00', 'iid': '851'}  | {'est': '5.00', 'iid': '1642'} | {'est': '4.27', 'iid': '1449'} |
# |  7 | {'est': '5.00', 'iid': '1495'} | {'est': '5.00', 'iid': '1639'} | {'est': '4.26', 'iid': '1653'} |
# |  8 | {'est': '5.00', 'iid': '1427'} | {'est': '5.00', 'iid': '1653'} | {'est': '4.23', 'iid': '1500'} |
# |  9 | {'est': '5.00', 'iid': '1599'} | {'est': '5.00', 'iid': '1599'} | {'est': '4.16', 'iid': '838'}  |

# %% [markdown]
# ### Non-negative Matrix Factorization

# %%
# %run experiments/nmf.py
# Out:
# ■ ■ ■ NMF ■ ■ ■
# ■ Performing random sampling on the dataset
# ■ Performing Grid Search
# ------------
# Parameters combination 1 of 4
# params:  {'n_factors': 15, 'n_epochs': 50}
# ------------
# Mean RMSE: 0.9798
# ------------
# ------------
# Parameters combination 2 of 4
# params:  {'n_factors': 15, 'n_epochs': 100}
# ------------
# Mean RMSE: 0.9769
# ------------
# ------------
# Parameters combination 3 of 4
# params:  {'n_factors': 20, 'n_epochs': 50}
# ------------
# Mean RMSE: 0.9814
# ------------
# ------------
# Parameters combination 4 of 4
# params:  {'n_factors': 20, 'n_epochs': 100}
# ------------
# Mean RMSE: 0.9732
# ------------
# ■ Grid Search completed. Here is the summary:
#        RMSE  n_factors                              params  \
# 3  0.973215         20  {'n_factors': 20, 'n_epochs': 100}
# 1  0.976931         15  {'n_factors': 15, 'n_epochs': 100}
# 0  0.979830         15   {'n_factors': 15, 'n_epochs': 50}
# 2  0.981369         20   {'n_factors': 20, 'n_epochs': 50}
#
#                      scores
# 3  {'RMSE': 0.973215117391}
# 1  {'RMSE': 0.976930868003}
# 0   {'RMSE': 0.97983008421}
# 2  {'RMSE': 0.981369365096}
# ■ Algorithm properties:
# surprise.prediction_algorithms.matrix_factorization.NMF at 0x7fb971c117b8 (
#     biased = False,
#     bsl_options = {},
#     init_high = 1,
#     init_low = 0,
#     lr_bi = 0.005,
#     ...,
#     reg_pu = 0.06,
#     reg_qi = 0.06,
#     sim_options = {'user_based': True},
#     verbose = True
# )
# ■ Training using trainset
# Processing epoch 0
# Processing epoch 1
# Processing epoch 2
# Processing epoch 3
# Processing epoch 4
# Processing epoch 5
# Processing epoch 6
# Processing epoch 7
# Processing epoch 8
# Processing epoch 9
# Processing epoch 10
# Processing epoch 11
# Processing epoch 12
# Processing epoch 13
# Processing epoch 14
# Processing epoch 15
# Processing epoch 16
# Processing epoch 17
# Processing epoch 18
# Processing epoch 19
# Processing epoch 20
# Processing epoch 21
# Processing epoch 22
# Processing epoch 23
# Processing epoch 24
# Processing epoch 25
# Processing epoch 26
# Processing epoch 27
# Processing epoch 28
# Processing epoch 29
# Processing epoch 30
# Processing epoch 31
# Processing epoch 32
# Processing epoch 33
# Processing epoch 34
# Processing epoch 35
# Processing epoch 36
# Processing epoch 37
# Processing epoch 38
# Processing epoch 39
# Processing epoch 40
# Processing epoch 41
# Processing epoch 42
# Processing epoch 43
# Processing epoch 44
# Processing epoch 45
# Processing epoch 46
# Processing epoch 47
# Processing epoch 48
# Processing epoch 49
# Processing epoch 50
# Processing epoch 51
# Processing epoch 52
# Processing epoch 53
# Processing epoch 54
# Processing epoch 55
# Processing epoch 56
# Processing epoch 57
# Processing epoch 58
# Processing epoch 59
# Processing epoch 60
# Processing epoch 61
# Processing epoch 62
# Processing epoch 63
# Processing epoch 64
# Processing epoch 65
# Processing epoch 66
# Processing epoch 67
# Processing epoch 68
# Processing epoch 69
# Processing epoch 70
# Processing epoch 71
# Processing epoch 72
# Processing epoch 73
# Processing epoch 74
# Processing epoch 75
# Processing epoch 76
# Processing epoch 77
# Processing epoch 78
# Processing epoch 79
# Processing epoch 80
# Processing epoch 81
# Processing epoch 82
# Processing epoch 83
# Processing epoch 84
# Processing epoch 85
# Processing epoch 86
# Processing epoch 87
# Processing epoch 88
# Processing epoch 89
# Processing epoch 90
# Processing epoch 91
# Processing epoch 92
# Processing epoch 93
# Processing epoch 94
# Processing epoch 95
# Processing epoch 96
# Processing epoch 97
# Processing epoch 98
# Processing epoch 99
# ■ Evaluating using testset
# RMSE: 0.9444
# ■ Using the best estimator on full dataset
# ■ Saving the trained model
# The dump has been saved as file /home/vinhnguyen/code/recommender-notebook/experiments/trained_models/nmf
# ■ Accuracy scores:
# MAE:  0.8302
# RMSE: 1.0550
# ■ Time elapsed: 0:01:03
# ■ Recommendations:
# |    | 1                              | 2                              | 3                              |
# |----+--------------------------------+--------------------------------+--------------------------------|
# |  0 | {'est': '5.00', 'iid': '1463'} | {'est': '5.00', 'iid': '1368'} | {'est': '5.00', 'iid': '896'}  |
# |  1 | {'est': '4.98', 'iid': '1449'} | {'est': '5.00', 'iid': '899'}  | {'est': '4.97', 'iid': '850'}  |
# |  2 | {'est': '4.94', 'iid': '318'}  | {'est': '4.95', 'iid': '1449'} | {'est': '4.89', 'iid': '1558'} |
# |  3 | {'est': '4.91', 'iid': '1467'} | {'est': '4.93', 'iid': '481'}  | {'est': '4.84', 'iid': '641'}  |
# |  4 | {'est': '4.84', 'iid': '408'}  | {'est': '4.82', 'iid': '484'}  | {'est': '4.68', 'iid': '1240'} |
# |  5 | {'est': '4.80', 'iid': '1643'} | {'est': '4.80', 'iid': '641'}  | {'est': '4.65', 'iid': '9'}    |
# |  6 | {'est': '4.77', 'iid': '647'}  | {'est': '4.78', 'iid': '483'}  | {'est': '4.61', 'iid': '516'}  |
# |  7 | {'est': '4.76', 'iid': '512'}  | {'est': '4.75', 'iid': '513'}  | {'est': '4.61', 'iid': '1368'} |
# |  8 | {'est': '4.73', 'iid': '479'}  | {'est': '4.74', 'iid': '1558'} | {'est': '4.60', 'iid': '1367'} |
# |  9 | {'est': '4.73', 'iid': '1642'} | {'est': '4.71', 'iid': '1398'} | {'est': '4.58', 'iid': '1643'} |

# %% [markdown]
# ### SlopeOne

# %%
# %run experiments/slope_one.py
# Out:
# ■ ■ ■ SlopeOne ■ ■ ■
# ■ Performing random sampling on the dataset
# ■ Performing Grid Search
# ------------
# Parameters combination 1 of 1
# params:  {}
# ------------
# Mean RMSE: 0.9524
# ------------
# ■ Grid Search completed. Here is the summary:
#   params                    scores
# 0     {}  {'RMSE': 0.952419763287}
# ■ Algorithm properties:
# surprise.prediction_algorithms.slope_one.SlopeOne at 0x7fb951edb780 (
#     bsl_options = {},
#     sim_options = {'user_based': True},
#     verbose = True
# )
# ■ Training using trainset
# ■ Evaluating using testset
# RMSE: 0.9452
# ■ Using the best estimator on full dataset
# ■ Saving the trained model
# The dump has been saved as file /home/vinhnguyen/code/recommender-notebook/experiments/trained_models/slope_one
# ■ Accuracy scores:
# MAE:  0.7430
# RMSE: 0.9424
# ■ Time elapsed: 0:02:26
# ■ Recommendations:
# |    | 1                              | 2                              | 3                              |
# |----+--------------------------------+--------------------------------+--------------------------------|
# |  0 | {'est': '5.00', 'iid': '1463'} | {'est': '5.00', 'iid': '1602'} | {'est': '5.00', 'iid': '814'}  |
# |  1 | {'est': '5.00', 'iid': '1449'} | {'est': '5.00', 'iid': '1642'} | {'est': '4.93', 'iid': '868'}  |
# |  2 | {'est': '5.00', 'iid': '1642'} | {'est': '5.00', 'iid': '1158'} | {'est': '4.79', 'iid': '851'}  |
# |  3 | {'est': '5.00', 'iid': '1158'} | {'est': '5.00', 'iid': '868'}  | {'est': '4.53', 'iid': '1554'} |
# |  4 | {'est': '5.00', 'iid': '1643'} | {'est': '5.00', 'iid': '851'}  | {'est': '4.46', 'iid': '1449'} |
# |  5 | {'est': '5.00', 'iid': '1653'} | {'est': '5.00', 'iid': '1500'} | {'est': '4.44', 'iid': '114'}  |
# |  6 | {'est': '5.00', 'iid': '851'}  | {'est': '5.00', 'iid': '1467'} | {'est': '4.31', 'iid': '867'}  |
# |  7 | {'est': '5.00', 'iid': '1500'} | {'est': '5.00', 'iid': '1599'} | {'est': '4.22', 'iid': '1158'} |
# |  8 | {'est': '5.00', 'iid': '1554'} | {'est': '5.00', 'iid': '1450'} | {'est': '4.22', 'iid': '1599'} |
# |  9 | {'est': '5.00', 'iid': '1599'} | {'est': '5.00', 'iid': '814'}  | {'est': '4.17', 'iid': '1452'} |

# %% [markdown]
# ### SVD

# %%
# %run experiments/svd.py
# Out:
# ■ ■ ■ SVD ■ ■ ■
# ■ Performing random sampling on the dataset
# ■ Performing Grid Search
# ------------
# Parameters combination 1 of 4
# params:  {'n_factors': 100, 'reg_all': 0.01}
# ------------
# Mean RMSE: 0.9535
# ------------
# ------------
# Parameters combination 2 of 4
# params:  {'n_factors': 100, 'reg_all': 0.02}
# ------------
# Mean RMSE: 0.9476
# ------------
# ------------
# Parameters combination 3 of 4
# params:  {'n_factors': 150, 'reg_all': 0.01}
# ------------
# Mean RMSE: 0.9573
# ------------
# ------------
# Parameters combination 4 of 4
# params:  {'n_factors': 150, 'reg_all': 0.02}
# ------------
# Mean RMSE: 0.9495
# ------------
# ■ Grid Search completed. Here is the summary:
#        RMSE  n_factors                               params  \
# 1  0.947576        100  {'n_factors': 100, 'reg_all': 0.02}
# 3  0.949478        150  {'n_factors': 150, 'reg_all': 0.02}
# 0  0.953550        100  {'n_factors': 100, 'reg_all': 0.01}
# 2  0.957283        150  {'n_factors': 150, 'reg_all': 0.01}
#
#                      scores
# 1  {'RMSE': 0.947575953182}
# 3  {'RMSE': 0.949478250077}
# 0  {'RMSE': 0.953549619357}
# 2  {'RMSE': 0.957283454316}
# ■ Algorithm properties:
# surprise.prediction_algorithms.matrix_factorization.SVD at 0x7fb96262fc18 (
#     biased = True,
#     bsl_options = {},
#     init_mean = 0,
#     init_std_dev = 0.1,
#     lr_bi = 0.005,
#     ...,
#     reg_pu = 0.02,
#     reg_qi = 0.02,
#     sim_options = {'user_based': True},
#     verbose = True
# )
# ■ Training using trainset
# Processing epoch 0
# Processing epoch 1
# Processing epoch 2
# Processing epoch 3
# Processing epoch 4
# Processing epoch 5
# Processing epoch 6
# Processing epoch 7
# Processing epoch 8
# Processing epoch 9
# Processing epoch 10
# Processing epoch 11
# Processing epoch 12
# Processing epoch 13
# Processing epoch 14
# Processing epoch 15
# Processing epoch 16
# Processing epoch 17
# Processing epoch 18
# Processing epoch 19
# ■ Evaluating using testset
# RMSE: 0.9353
# ■ Using the best estimator on full dataset
# ■ Saving the trained model
# The dump has been saved as file /home/vinhnguyen/code/recommender-notebook/experiments/trained_models/svd
# ■ Accuracy scores:
# MAE:  0.4629
# RMSE: 0.5878
# ■ Time elapsed: 0:01:05
# ■ Recommendations:
# |    | 1                             | 2                             | 3                             |
# |----+-------------------------------+-------------------------------+-------------------------------|
# |  0 | {'est': '4.87', 'iid': '50'}  | {'est': '4.69', 'iid': '64'}  | {'est': '4.16', 'iid': '199'} |
# |  1 | {'est': '4.81', 'iid': '408'} | {'est': '4.69', 'iid': '408'} | {'est': '4.10', 'iid': '923'} |
# |  2 | {'est': '4.68', 'iid': '357'} | {'est': '4.63', 'iid': '480'} | {'est': '4.08', 'iid': '513'} |
# |  3 | {'est': '4.66', 'iid': '180'} | {'est': '4.63', 'iid': '318'} | {'est': '4.08', 'iid': '98'}  |
# |  4 | {'est': '4.65', 'iid': '515'} | {'est': '4.61', 'iid': '134'} | {'est': '4.08', 'iid': '169'} |
# |  5 | {'est': '4.57', 'iid': '114'} | {'est': '4.61', 'iid': '12'}  | {'est': '4.07', 'iid': '100'} |
# |  6 | {'est': '4.56', 'iid': '170'} | {'est': '4.55', 'iid': '98'}  | {'est': '4.07', 'iid': '12'}  |
# |  7 | {'est': '4.53', 'iid': '675'} | {'est': '4.54', 'iid': '474'} | {'est': '4.06', 'iid': '209'} |
# |  8 | {'est': '4.50', 'iid': '498'} | {'est': '4.53', 'iid': '427'} | {'est': '4.06', 'iid': '529'} |
# |  9 | {'est': '4.48', 'iid': '483'} | {'est': '4.52', 'iid': '357'} | {'est': '4.05', 'iid': '478'} |

# %% [markdown]
# ### SVD++

# %%
# %run experiments/svdpp.py
# Out:
# ■ ■ ■ SVDpp ■ ■ ■
# ■ Performing random sampling on the dataset
# ■ Performing Grid Search
# ------------
# Parameters combination 1 of 4
# params:  {'reg_all': 0.01, 'n_epochs': 10}
# ------------
# Mean RMSE: 0.9352
# ------------
# ------------
# Parameters combination 2 of 4
# params:  {'reg_all': 0.01, 'n_epochs': 20}
# ------------
# Mean RMSE: 0.9364
# ------------
# ------------
# Parameters combination 3 of 4
# params:  {'reg_all': 0.02, 'n_epochs': 10}
# ------------
# Mean RMSE: 0.9398
# ------------
# ------------
# Parameters combination 4 of 4
# params:  {'reg_all': 0.02, 'n_epochs': 20}
# ------------
# Mean RMSE: 0.9334
# ------------
# ■ Grid Search completed. Here is the summary:
#        RMSE                             params  reg_all  \
# 3  0.933440  {'reg_all': 0.02, 'n_epochs': 20}     0.02
# 0  0.935249  {'reg_all': 0.01, 'n_epochs': 10}     0.01
# 1  0.936420  {'reg_all': 0.01, 'n_epochs': 20}     0.01
# 2  0.939758  {'reg_all': 0.02, 'n_epochs': 10}     0.02
#
#                      scores
# 3  {'RMSE': 0.933440152399}
# 0   {'RMSE': 0.93524945945}
# 1  {'RMSE': 0.936419785855}
# 2  {'RMSE': 0.939757862436}
# ■ Algorithm properties:
# surprise.prediction_algorithms.matrix_factorization.SVDpp at 0x7fb94ecaec88 (
#     bsl_options = {},
#     init_mean = 0,
#     init_std_dev = 0.1,
#     lr_bi = 0.007,
#     lr_bu = 0.007,
#     ...,
#     reg_qi = 0.02,
#     reg_yj = 0.02,
#     sim_options = {'user_based': True},
#     verbose = True
# )
# ■ Training using trainset
#  processing epoch 0
#  processing epoch 1
#  processing epoch 2
#  processing epoch 3
#  processing epoch 4
#  processing epoch 5
#  processing epoch 6
#  processing epoch 7
#  processing epoch 8
#  processing epoch 9
#  processing epoch 10
#  processing epoch 11
#  processing epoch 12
#  processing epoch 13
#  processing epoch 14
#  processing epoch 15
#  processing epoch 16
#  processing epoch 17
#  processing epoch 18
#  processing epoch 19
# ■ Evaluating using testset
# RMSE: 0.9075
# ■ Using the best estimator on full dataset
# ■ Saving the trained model
# The dump has been saved as file /home/vinhnguyen/code/recommender-notebook/experiments/trained_models/svdpp
# ■ Accuracy scores:
# MAE:  0.4967
# RMSE: 0.6328
# ■ Time elapsed: 0:04:02
# ■ Recommendations:
# |    | 1                              | 2                             | 3                             |
# |----+--------------------------------+-------------------------------+-------------------------------|
# |  0 | {'est': '5.00', 'iid': '483'}  | {'est': '4.97', 'iid': '50'}  | {'est': '4.21', 'iid': '357'} |
# |  1 | {'est': '5.00', 'iid': '408'}  | {'est': '4.84', 'iid': '408'} | {'est': '4.21', 'iid': '480'} |
# |  2 | {'est': '5.00', 'iid': '493'}  | {'est': '4.73', 'iid': '169'} | {'est': '4.14', 'iid': '64'}  |
# |  3 | {'est': '4.99', 'iid': '656'}  | {'est': '4.70', 'iid': '483'} | {'est': '4.13', 'iid': '408'} |
# |  4 | {'est': '4.97', 'iid': '1449'} | {'est': '4.67', 'iid': '318'} | {'est': '4.11', 'iid': '114'} |
# |  5 | {'est': '4.92', 'iid': '510'}  | {'est': '4.64', 'iid': '172'} | {'est': '4.09', 'iid': '132'} |
# |  6 | {'est': '4.91', 'iid': '511'}  | {'est': '4.63', 'iid': '64'}  | {'est': '4.09', 'iid': '483'} |
# |  7 | {'est': '4.90', 'iid': '513'}  | {'est': '4.61', 'iid': '12'}  | {'est': '4.09', 'iid': '427'} |
# |  8 | {'est': '4.88', 'iid': '647'}  | {'est': '4.61', 'iid': '178'} | {'est': '4.08', 'iid': '527'} |
# |  9 | {'est': '4.81', 'iid': '519'}  | {'est': '4.60', 'iid': '427'} | {'est': '4.05', 'iid': '423'} |

# %% [markdown]
# ### Visualizing the movie-lens dataset

# %%
import os
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt

def load_data_into_dataframe(path):
    if not os.path.exists(path):
        raise RuntimeError('Cannot find the given dataset!')
    df = pd.read_csv(path, sep='\t', names=['UserID', 'ItemID', 'Rating', 'Timestamp'])
    return df

path = os.path.expanduser('~/.surprise_data/ml-100k/ml-100k/u.data')
df = load_data_into_dataframe(path)

# %%
print(df.shape)
# Out:
# (100000, 4)

# %%
print(df.columns)
# Out:
# Index(['UserID', 'ItemID', 'Rating', 'Timestamp'], dtype='object')

# %%
print(df.head())
# Out:
#    UserID  ItemID  Rating  Timestamp
# 0     196     242       3  881250949
# 1     186     302       3  891717742
# 2      22     377       1  878887116
# 3     244      51       2  880606923
# 4     166     346       1  886397596

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 4 columns):
# UserID       100000 non-null int64
# ItemID       100000 non-null int64
# Rating       100000 non-null int64
# Timestamp    100000 non-null int64
# dtypes: int64(4)
# memory usage: 3.1 MB
# None

# %%
print(df.describe())
# Out:
#              UserID         ItemID         Rating     Timestamp
# count  100000.00000  100000.000000  100000.000000  1.000000e+05
# mean      462.48475     425.530130       3.529860  8.835289e+08
# std       266.61442     330.798356       1.125674  5.343856e+06
# min         1.00000       1.000000       1.000000  8.747247e+08
# 25%       254.00000     175.000000       3.000000  8.794487e+08
# 50%       447.00000     322.000000       4.000000  8.828269e+08
# 75%       682.00000     631.000000       4.000000  8.882600e+08
# max       943.00000    1682.000000       5.000000  8.932866e+08

# %%
plt.hist(df['Rating'])
# Out:
# (array([  6110.,      0.,  11370.,      0.,      0.,  27145.,      0.,
#          34174.,      0.,  21201.]),
#  array([ 1. ,  1.4,  1.8,  2.2,  2.6,  3. ,  3.4,  3.8,  4.2,  4.6,  5. ]),
#  <a list of 10 Patch objects>)

# %%
df.groupby(['Rating'])['UserID'].count()
# Out:
# Rating
# 1     6110
# 2    11370
# 3    27145
# 4    34174
# 5    21201
# Name: UserID, dtype: int64

# %%
plt.hist(df.groupby(['ItemID'])['ItemID'].count())
# Out:
# (array([  1.14600000e+03,   2.49000000e+02,   1.39000000e+02,
#           6.70000000e+01,   3.80000000e+01,   2.40000000e+01,
#           7.00000000e+00,   5.00000000e+00,   6.00000000e+00,
#           1.00000000e+00]),
#  array([   1. ,   59.2,  117.4,  175.6,  233.8,  292. ,  350.2,  408.4,
#          466.6,  524.8,  583. ]),
#  <a list of 10 Patch objects>)
