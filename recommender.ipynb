# %%
import os
import sys
from rs import parse_config

path = parse_config(section='Path', key='package')
module = os.path.expanduser(path)
if os.path.exists(module) and module not in sys.path:
    sys.path.append(module)

# %% [markdown]
# ### BaselineOnly

# %%
# %run experiments/baseline_only.py
# Out:
# ■ ■ ■ BaselineOnly ■ ■ ■
# ■ Performing random sampling on the dataset
# ■ Performing Grid Search
# ------------
# Parameters combination 1 of 2
# params:  {'bsl_options': {'method': 'als', 'n_epochs': 30}}
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# ------------
# Mean RMSE: 0.9468
# ------------
# ------------
# Parameters combination 2 of 2
# params:  {'bsl_options': {'method': 'sgd', 'learning_rate': 0.0007, 'n_epochs': 30}}
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# ------------
# Mean RMSE: 0.9628
# ------------
# ■ Grid Search completed. Here is the summary:
#        RMSE                                        bsl_options  \
# 0  0.946839                  {'method': 'als', 'n_epochs': 30}
# 1  0.962794  {'method': 'sgd', 'learning_rate': 0.0007, 'n_...
#
#                                               params                    scores
# 0  {'bsl_options': {'method': 'als', 'n_epochs': ...  {'RMSE': 0.946838995647}
# 1  {'bsl_options': {'method': 'sgd', 'learning_ra...  {'RMSE': 0.962793732931}
# ■ Algorithm properties:
# surprise.prediction_algorithms.baseline_only.BaselineOnly at 0x7fea280d4e80 (
#     bsl_options = {'method': 'als', 'n_epochs': 30},
#     sim_options = {'user_based': True},
#     verbose = True
# )
# ■ Training using trainset
# Estimating biases using als...
# ■ Evaluating using testset
# RMSE: 0.9478
# ■ Using the best estimator on full dataset
# ■ Saving the trained model
# The dump has been saved as file /home/local/FRAMGIA/nguyen.ngoc.vinh/code/recommender/experiments/trained_models/baseline_only
# ■ Accuracy scores:
# MAE:  0.3902
# RMSE: 0.4970
# ■ Time elapsed: 0:00:33
# ■ Recommendations:
# |    | 1                             | 2                             | 3                             |
# |----+-------------------------------+-------------------------------+-------------------------------|
# |  0 | {'iid': '318', 'est': '4.46'} | {'iid': '318', 'est': '4.53'} | {'iid': '483', 'est': '4.07'} |
# |  1 | {'iid': '483', 'est': '4.45'} | {'iid': '483', 'est': '4.52'} | {'iid': '169', 'est': '4.06'} |
# |  2 | {'iid': '169', 'est': '4.43'} | {'iid': '169', 'est': '4.51'} | {'iid': '64', 'est': '4.04'}  |
# |  3 | {'iid': '408', 'est': '4.41'} | {'iid': '64', 'est': '4.49'}  | {'iid': '408', 'est': '4.04'} |
# |  4 | {'iid': '12', 'est': '4.37'}  | {'iid': '408', 'est': '4.49'} | {'iid': '12', 'est': '3.99'}  |
# |  5 | {'iid': '603', 'est': '4.31'} | {'iid': '12', 'est': '4.44'}  | {'iid': '50', 'est': '3.94'}  |
# |  6 | {'iid': '357', 'est': '4.28'} | {'iid': '603', 'est': '4.38'} | {'iid': '603', 'est': '3.94'} |
# |  7 | {'iid': '515', 'est': '4.27'} | {'iid': '127', 'est': '4.35'} | {'iid': '127', 'est': '3.91'} |
# |  8 | {'iid': '98', 'est': '4.25'}  | {'iid': '357', 'est': '4.35'} | {'iid': '357', 'est': '3.90'} |
# |  9 | {'iid': '513', 'est': '4.25'} | {'iid': '515', 'est': '4.35'} | {'iid': '515', 'est': '3.90'} |

# %% [markdown]
# ### CoClustering

# %%
# %run experiments/co_clustering.py
# Out:
# ■ ■ ■ CoClustering ■ ■ ■
# ■ Performing random sampling on the dataset
# ■ Performing Grid Search
# ------------
# Parameters combination 1 of 8
# params:  {'n_cltr_u': 3, 'n_cltr_i': 3, 'n_epochs': 20}
# ------------
# Mean RMSE: 0.9764
# ------------
# ------------
# Parameters combination 2 of 8
# params:  {'n_cltr_u': 3, 'n_cltr_i': 3, 'n_epochs': 60}
# ------------
# Mean RMSE: 0.9783
# ------------
# ------------
# Parameters combination 3 of 8
# params:  {'n_cltr_u': 3, 'n_cltr_i': 5, 'n_epochs': 20}
# ------------
# Mean RMSE: 0.9767
# ------------
# ------------
# Parameters combination 4 of 8
# params:  {'n_cltr_u': 3, 'n_cltr_i': 5, 'n_epochs': 60}
# ------------
# Mean RMSE: 0.9760
# ------------
# ------------
# Parameters combination 5 of 8
# params:  {'n_cltr_u': 5, 'n_cltr_i': 3, 'n_epochs': 20}
# ------------
# Mean RMSE: 0.9752
# ------------
# ------------
# Parameters combination 6 of 8
# params:  {'n_cltr_u': 5, 'n_cltr_i': 3, 'n_epochs': 60}
# ------------
# Mean RMSE: 0.9720
# ------------
# ------------
# Parameters combination 7 of 8
# params:  {'n_cltr_u': 5, 'n_cltr_i': 5, 'n_epochs': 20}
# ------------
# Mean RMSE: 0.9866
# ------------
# ------------
# Parameters combination 8 of 8
# params:  {'n_cltr_u': 5, 'n_cltr_i': 5, 'n_epochs': 60}
# ------------
# Mean RMSE: 0.9860
# ------------
# ■ Grid Search completed. Here is the summary:
#        RMSE  n_cltr_u                                          params  \
# 5  0.971987         5  {'n_cltr_u': 5, 'n_cltr_i': 3, 'n_epochs': 60}
# 4  0.975158         5  {'n_cltr_u': 5, 'n_cltr_i': 3, 'n_epochs': 20}
# 3  0.975962         3  {'n_cltr_u': 3, 'n_cltr_i': 5, 'n_epochs': 60}
# 0  0.976402         3  {'n_cltr_u': 3, 'n_cltr_i': 3, 'n_epochs': 20}
# 2  0.976708         3  {'n_cltr_u': 3, 'n_cltr_i': 5, 'n_epochs': 20}
# 1  0.978273         3  {'n_cltr_u': 3, 'n_cltr_i': 3, 'n_epochs': 60}
# 7  0.985985         5  {'n_cltr_u': 5, 'n_cltr_i': 5, 'n_epochs': 60}
# 6  0.986608         5  {'n_cltr_u': 5, 'n_cltr_i': 5, 'n_epochs': 20}
#
#                      scores
# 5  {'RMSE': 0.971986510843}
# 4  {'RMSE': 0.975157748176}
# 3  {'RMSE': 0.975962379533}
# 0  {'RMSE': 0.976402369842}
# 2  {'RMSE': 0.976708088866}
# 1  {'RMSE': 0.978273007168}
# 7  {'RMSE': 0.985985238426}
# 6  {'RMSE': 0.986608147469}
# ■ Algorithm properties:
# surprise.prediction_algorithms.co_clustering.CoClustering at 0x7fea2833ddd8 (
#     bsl_options = {},
#     n_cltr_i = 3,
#     n_cltr_u = 5,
#     n_epochs = 60,
#     sim_options = {'user_based': True},
#     verbose = True
# )
# ■ Training using trainset
# Processing epoch 0
# Processing epoch 1
# Processing epoch 2
# Processing epoch 3
# Processing epoch 4
# Processing epoch 5
# Processing epoch 6
# Processing epoch 7
# Processing epoch 8
# Processing epoch 9
# Processing epoch 10
# Processing epoch 11
# Processing epoch 12
# Processing epoch 13
# Processing epoch 14
# Processing epoch 15
# Processing epoch 16
# Processing epoch 17
# Processing epoch 18
# Processing epoch 19
# Processing epoch 20
# Processing epoch 21
# Processing epoch 22
# Processing epoch 23
# Processing epoch 24
# Processing epoch 25
# Processing epoch 26
# Processing epoch 27
# Processing epoch 28
# Processing epoch 29
# Processing epoch 30
# Processing epoch 31
# Processing epoch 32
# Processing epoch 33
# Processing epoch 34
# Processing epoch 35
# Processing epoch 36
# Processing epoch 37
# Processing epoch 38
# Processing epoch 39
# Processing epoch 40
# Processing epoch 41
# Processing epoch 42
# Processing epoch 43
# Processing epoch 44
# Processing epoch 45
# Processing epoch 46
# Processing epoch 47
# Processing epoch 48
# Processing epoch 49
# Processing epoch 50
# Processing epoch 51
# Processing epoch 52
# Processing epoch 53
# Processing epoch 54
# Processing epoch 55
# Processing epoch 56
# Processing epoch 57
# Processing epoch 58
# Processing epoch 59
# ■ Evaluating using testset
# RMSE: 0.9643
# ■ Using the best estimator on full dataset
# ■ Saving the trained model
# The dump has been saved as file /home/local/FRAMGIA/nguyen.ngoc.vinh/code/recommender/experiments/trained_models/co_clustering
# ■ Accuracy scores:
# MAE:  0.7893
# RMSE: 1.0121
# ■ Time elapsed: 0:00:29
# ■ Recommendations:
# |    | 1                              | 2                              | 3                              |
# |----+--------------------------------+--------------------------------+--------------------------------|
# |  0 | {'iid': '1642', 'est': '5.00'} | {'iid': '1642', 'est': '5.00'} | {'iid': '1189', 'est': '4.70'} |
# |  1 | {'iid': '1467', 'est': '5.00'} | {'iid': '1467', 'est': '5.00'} | {'iid': '1536', 'est': '4.70'} |
# |  2 | {'iid': '1189', 'est': '5.00'} | {'iid': '1293', 'est': '5.00'} | {'iid': '1642', 'est': '4.56'} |
# |  3 | {'iid': '1122', 'est': '5.00'} | {'iid': '1201', 'est': '5.00'} | {'iid': '1467', 'est': '4.56'} |
# |  4 | {'iid': '1612', 'est': '5.00'} | {'iid': '1599', 'est': '5.00'} | {'iid': '1122', 'est': '4.56'} |
# |  5 | {'iid': '1536', 'est': '5.00'} | {'iid': '1122', 'est': '5.00'} | {'iid': '1612', 'est': '4.56'} |
# |  6 | {'iid': '1500', 'est': '5.00'} | {'iid': '814', 'est': '5.00'}  | {'iid': '1500', 'est': '4.56'} |
# |  7 | {'iid': '1639', 'est': '4.89'} | {'iid': '1612', 'est': '5.00'} | {'iid': '1639', 'est': '4.20'} |
# |  8 | {'iid': '1398', 'est': '4.89'} | {'iid': '1500', 'est': '5.00'} | {'iid': '1398', 'est': '4.20'} |
# |  9 | {'iid': '1355', 'est': '4.89'} | {'iid': '1653', 'est': '5.00'} | {'iid': '119', 'est': '4.20'}  |

# %% [markdown]
# ### KNNBaseline

# %%
# %run experiments/knn_baseline.py
# Out:
# ■ ■ ■ KNNBaseline ■ ■ ■
# ■ Performing random sampling on the dataset
# ■ Performing Grid Search
# ------------
# Parameters combination 1 of 8
# params:  {'sim_options': {'name': 'cosine'}, 'bsl_options': {'method': 'als', 'n_epochs': 30}, 'k': 20}
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9489
# ------------
# ------------
# Parameters combination 2 of 8
# params:  {'sim_options': {'user_based': True, 'name': 'cosine'}, 'bsl_options': {'method': 'als', 'n_epochs': 30}, 'k': 40}
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9416
# ------------
# ------------
# Parameters combination 3 of 8
# params:  {'sim_options': {'user_based': True, 'name': 'cosine'}, 'bsl_options': {'method': 'sgd', 'learning_rate': 0.0007, 'n_epochs': 30}, 'k': 20}
# Estimating biases using sgd...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9549
# ------------
# ------------
# Parameters combination 4 of 8
# params:  {'sim_options': {'user_based': True, 'name': 'cosine'}, 'bsl_options': {'method': 'sgd', 'learning_rate': 0.0007, 'n_epochs': 30}, 'k': 40}
# Estimating biases using sgd...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9472
# ------------
# ------------
# Parameters combination 5 of 8
# params:  {'sim_options': {'shrinkage': 150, 'name': 'pearson_baseline'}, 'bsl_options': {'method': 'als', 'n_epochs': 30}, 'k': 20}
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9375
# ------------
# ------------
# Parameters combination 6 of 8
# params:  {'sim_options': {'shrinkage': 150, 'name': 'pearson_baseline', 'user_based': True}, 'bsl_options': {'method': 'als', 'n_epochs': 30}, 'k': 40}
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9347
# ------------
# ------------
# Parameters combination 7 of 8
# params:  {'sim_options': {'shrinkage': 150, 'name': 'pearson_baseline', 'user_based': True}, 'bsl_options': {'method': 'sgd', 'learning_rate': 0.0007, 'n_epochs': 30}, 'k': 20}
# Estimating biases using sgd...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9399
# ------------
# ------------
# Parameters combination 8 of 8
# params:  {'sim_options': {'shrinkage': 150, 'name': 'pearson_baseline', 'user_based': True}, 'bsl_options': {'method': 'sgd', 'learning_rate': 0.0007, 'n_epochs': 30}, 'k': 40}
# Estimating biases using sgd...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9368
# ------------
# ■ Grid Search completed. Here is the summary:
#        RMSE                                             params  \
# 5  0.934670  {'sim_options': {'shrinkage': 150, 'name': 'pe...
# 7  0.936844  {'sim_options': {'shrinkage': 150, 'name': 'pe...
# 4  0.937540  {'sim_options': {'shrinkage': 150, 'name': 'pe...
# 6  0.939869  {'sim_options': {'shrinkage': 150, 'name': 'pe...
# 1  0.941563  {'sim_options': {'user_based': True, 'name': '...
# 3  0.947221  {'sim_options': {'user_based': True, 'name': '...
# 0  0.948866  {'sim_options': {'user_based': True, 'name': '...
# 2  0.954861  {'sim_options': {'user_based': True, 'name': '...
#
#                      scores                                        sim_options
# 5  {'RMSE': 0.934669935356}  {'shrinkage': 150, 'name': 'pearson_baseline',...
# 7  {'RMSE': 0.936843970095}  {'shrinkage': 150, 'name': 'pearson_baseline',...
# 4    {'RMSE': 0.9375400326}  {'shrinkage': 150, 'name': 'pearson_baseline',...
# 6  {'RMSE': 0.939869316453}  {'shrinkage': 150, 'name': 'pearson_baseline',...
# 1  {'RMSE': 0.941562543665}             {'user_based': True, 'name': 'cosine'}
# 3  {'RMSE': 0.947221468129}             {'user_based': True, 'name': 'cosine'}
# 0  {'RMSE': 0.948866343542}             {'user_based': True, 'name': 'cosine'}
# 2  {'RMSE': 0.954861113893}             {'user_based': True, 'name': 'cosine'}
# ■ Algorithm properties:
# surprise.prediction_algorithms.knns.KNNBaseline at 0x7fe9f571b710 (
#     bsl_options = {'method': 'als', 'n_epochs': 30},
#     k = 40,
#     min_k = 1,
#     sim_options = {'shrinkage': 150, 'name': 'pearson_baseline', 'user_based': True},
#     verbose = True
# )
# ■ Training using trainset
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# ■ Evaluating using testset
# RMSE: 0.9267
# ■ Using the best estimator on full dataset
# ■ Saving the trained model
# The dump has been saved as file /home/local/FRAMGIA/nguyen.ngoc.vinh/code/recommender/experiments/trained_models/knn_baseline
# ■ Accuracy scores:
# MAE:  0.6339
# RMSE: 0.8205
# ■ Time elapsed: 0:01:43
# ■ Recommendations:
# |    | 1                              | 2                              | 3                              |
# |----+--------------------------------+--------------------------------+--------------------------------|
# |  0 | {'iid': '867', 'est': '5.00'}  | {'iid': '1629', 'est': '5.00'} | {'iid': '1368', 'est': '5.00'} |
# |  1 | {'iid': '793', 'est': '5.00'}  | {'iid': '1449', 'est': '5.00'} | {'iid': '1463', 'est': '5.00'} |
# |  2 | {'iid': '1467', 'est': '5.00'} | {'iid': '1174', 'est': '5.00'} | {'iid': '1643', 'est': '5.00'} |
# |  3 | {'iid': '1628', 'est': '5.00'} | {'iid': '1368', 'est': '5.00'} | {'iid': '1554', 'est': '5.00'} |
# |  4 | {'iid': '851', 'est': '5.00'}  | {'iid': '1628', 'est': '5.00'} | {'iid': '113', 'est': '4.98'}  |
# |  5 | {'iid': '1405', 'est': '5.00'} | {'iid': '1599', 'est': '5.00'} | {'iid': '1449', 'est': '4.76'} |
# |  6 | {'iid': '1599', 'est': '5.00'} | {'iid': '1463', 'est': '5.00'} | {'iid': '1642', 'est': '4.69'} |
# |  7 | {'iid': '1367', 'est': '5.00'} | {'iid': '868', 'est': '5.00'}  | {'iid': '1491', 'est': '4.63'} |
# |  8 | {'iid': '1500', 'est': '5.00'} | {'iid': '1642', 'est': '5.00'} | {'iid': '1500', 'est': '4.63'} |
# |  9 | {'iid': '1642', 'est': '5.00'} | {'iid': '1639', 'est': '5.00'} | {'iid': '1358', 'est': '4.37'} |

# %% [markdown]
# ### KNNBasic

# %%
# %run experiments/knn_basic.py
# Out:
# ■ ■ ■ KNNBasic ■ ■ ■
# ■ Performing random sampling on the dataset
# ■ Performing Grid Search
# ------------
# Parameters combination 1 of 10
# params:  {'sim_options': {'name': 'msd'}, 'k': 20}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9894
# ------------
# ------------
# Parameters combination 2 of 10
# params:  {'sim_options': {'user_based': True, 'name': 'msd'}, 'k': 40}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9902
# ------------
# ------------
# Parameters combination 3 of 10
# params:  {'sim_options': {'name': 'cosine'}, 'k': 20}
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 1.0306
# ------------
# ------------
# Parameters combination 4 of 10
# params:  {'sim_options': {'user_based': True, 'name': 'cosine'}, 'k': 40}
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 1.0222
# ------------
# ------------
# Parameters combination 5 of 10
# params:  {'sim_options': {'name': 'pearson'}, 'k': 20}
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 1.0306
# ------------
# ------------
# Parameters combination 6 of 10
# params:  {'sim_options': {'user_based': True, 'name': 'pearson'}, 'k': 40}
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 1.0227
# ------------
# ------------
# Parameters combination 7 of 10
# params:  {'sim_options': {'name': 'pearson_baseline'}, 'k': 20}
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 1.0169
# ------------
# ------------
# Parameters combination 8 of 10
# params:  {'sim_options': {'user_based': True, 'name': 'pearson_baseline'}, 'k': 40}
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 1.0142
# ------------
# ------------
# Parameters combination 9 of 10
# params:  {'sim_options': {'shrinkage': 150, 'name': 'pearson_baseline'}, 'k': 20}
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 1.0169
# ------------
# ------------
# Parameters combination 10 of 10
# params:  {'sim_options': {'shrinkage': 150, 'name': 'pearson_baseline', 'user_based': True}, 'k': 40}
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 1.0142
# ------------
# ■ Grid Search completed. Here is the summary:
#        RMSE                                             params  \
# 0  0.989422  {'sim_options': {'user_based': True, 'name': '...
# 1  0.990160  {'sim_options': {'user_based': True, 'name': '...
# 7  1.014224  {'sim_options': {'user_based': True, 'name': '...
# 9  1.014240  {'sim_options': {'shrinkage': 150, 'name': 'pe...
# 8  1.016880  {'sim_options': {'shrinkage': 150, 'name': 'pe...
# 6  1.016881  {'sim_options': {'user_based': True, 'name': '...
# 3  1.022198  {'sim_options': {'user_based': True, 'name': '...
# 5  1.022674  {'sim_options': {'user_based': True, 'name': '...
# 2  1.030558  {'sim_options': {'user_based': True, 'name': '...
# 4  1.030629  {'sim_options': {'user_based': True, 'name': '...
#
#                      scores                                        sim_options
# 0  {'RMSE': 0.989422421266}                {'user_based': True, 'name': 'msd'}
# 1  {'RMSE': 0.990160418079}                {'user_based': True, 'name': 'msd'}
# 7   {'RMSE': 1.01422383418}   {'user_based': True, 'name': 'pearson_baseline'}
# 9   {'RMSE': 1.01424005161}  {'shrinkage': 150, 'name': 'pearson_baseline',...
# 8   {'RMSE': 1.01687973115}  {'shrinkage': 150, 'name': 'pearson_baseline',...
# 6   {'RMSE': 1.01688128507}   {'user_based': True, 'name': 'pearson_baseline'}
# 3   {'RMSE': 1.02219831173}             {'user_based': True, 'name': 'cosine'}
# 5   {'RMSE': 1.02267409968}            {'user_based': True, 'name': 'pearson'}
# 2   {'RMSE': 1.03055780007}             {'user_based': True, 'name': 'cosine'}
# 4   {'RMSE': 1.03062927488}            {'user_based': True, 'name': 'pearson'}
# ■ Algorithm properties:
# surprise.prediction_algorithms.knns.KNNBasic at 0x7fea25ab42e8 (
#     bsl_options = {},
#     k = 20,
#     min_k = 1,
#     sim_options = {'user_based': True, 'name': 'msd'},
#     verbose = True
# )
# ■ Training using trainset
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ■ Evaluating using testset
# RMSE: 0.9781
# ■ Using the best estimator on full dataset
# ■ Saving the trained model
# The dump has been saved as file /home/local/FRAMGIA/nguyen.ngoc.vinh/code/recommender/experiments/trained_models/knn_basic
# ■ Accuracy scores:
# MAE:  0.7060
# RMSE: 0.9389
# ■ Time elapsed: 0:01:27
# ■ Recommendations:
# |    | 1                              | 2                              | 3                              |
# |----+--------------------------------+--------------------------------+--------------------------------|
# |  0 | {'iid': '1599', 'est': '5.00'} | {'iid': '1599', 'est': '5.00'} | {'iid': '1599', 'est': '5.00'} |
# |  1 | {'iid': '1653', 'est': '5.00'} | {'iid': '1653', 'est': '5.00'} | {'iid': '1653', 'est': '5.00'} |
# |  2 | {'iid': '1467', 'est': '5.00'} | {'iid': '1467', 'est': '5.00'} | {'iid': '1467', 'est': '5.00'} |
# |  3 | {'iid': '1191', 'est': '5.00'} | {'iid': '1191', 'est': '5.00'} | {'iid': '1191', 'est': '5.00'} |
# |  4 | {'iid': '1189', 'est': '5.00'} | {'iid': '1189', 'est': '5.00'} | {'iid': '1189', 'est': '5.00'} |
# |  5 | {'iid': '1306', 'est': '5.00'} | {'iid': '1306', 'est': '5.00'} | {'iid': '1306', 'est': '5.00'} |
# |  6 | {'iid': '1201', 'est': '5.00'} | {'iid': '1201', 'est': '5.00'} | {'iid': '1201', 'est': '5.00'} |
# |  7 | {'iid': '1642', 'est': '5.00'} | {'iid': '1642', 'est': '5.00'} | {'iid': '1642', 'est': '5.00'} |
# |  8 | {'iid': '814', 'est': '5.00'}  | {'iid': '814', 'est': '5.00'}  | {'iid': '814', 'est': '5.00'}  |
# |  9 | {'iid': '1122', 'est': '5.00'} | {'iid': '1122', 'est': '5.00'} | {'iid': '1122', 'est': '5.00'} |

# %% [markdown]
# ### KNNWithMeans

# %%
# %run experiments/knn_with_means.py
# Out:
# ■ ■ ■ KNNWithMeans ■ ■ ■
# ■ Performing random sampling on the dataset
# ■ Performing Grid Search
# ------------
# Parameters combination 1 of 10
# params:  {'sim_options': {'name': 'msd'}, 'k': 20}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9652
# ------------
# ------------
# Parameters combination 2 of 10
# params:  {'sim_options': {'user_based': True, 'name': 'msd'}, 'k': 40}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9589
# ------------
# ------------
# Parameters combination 3 of 10
# params:  {'sim_options': {'name': 'cosine'}, 'k': 20}
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9731
# ------------
# ------------
# Parameters combination 4 of 10
# params:  {'sim_options': {'user_based': True, 'name': 'cosine'}, 'k': 40}
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9637
# ------------
# ------------
# Parameters combination 5 of 10
# params:  {'sim_options': {'name': 'pearson'}, 'k': 20}
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9680
# ------------
# ------------
# Parameters combination 6 of 10
# params:  {'sim_options': {'user_based': True, 'name': 'pearson'}, 'k': 40}
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9601
# ------------
# ------------
# Parameters combination 7 of 10
# params:  {'sim_options': {'name': 'pearson_baseline'}, 'k': 20}
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9539
# ------------
# ------------
# Parameters combination 8 of 10
# params:  {'sim_options': {'user_based': True, 'name': 'pearson_baseline'}, 'k': 40}
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9521
# ------------
# ------------
# Parameters combination 9 of 10
# params:  {'sim_options': {'shrinkage': 150, 'name': 'pearson_baseline'}, 'k': 20}
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9540
# ------------
# ------------
# Parameters combination 10 of 10
# params:  {'sim_options': {'shrinkage': 150, 'name': 'pearson_baseline', 'user_based': True}, 'k': 40}
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9520
# ------------
# ■ Grid Search completed. Here is the summary:
#        RMSE                                             params  \
# 9  0.951994  {'sim_options': {'shrinkage': 150, 'name': 'pe...
# 7  0.952117  {'sim_options': {'user_based': True, 'name': '...
# 6  0.953928  {'sim_options': {'user_based': True, 'name': '...
# 8  0.953955  {'sim_options': {'shrinkage': 150, 'name': 'pe...
# 1  0.958869  {'sim_options': {'user_based': True, 'name': '...
# 5  0.960091  {'sim_options': {'user_based': True, 'name': '...
# 3  0.963704  {'sim_options': {'user_based': True, 'name': '...
# 0  0.965244  {'sim_options': {'user_based': True, 'name': '...
# 4  0.967997  {'sim_options': {'user_based': True, 'name': '...
# 2  0.973061  {'sim_options': {'user_based': True, 'name': '...
#
#                      scores                                        sim_options
# 9  {'RMSE': 0.951993694739}  {'shrinkage': 150, 'name': 'pearson_baseline',...
# 7  {'RMSE': 0.952116522391}   {'user_based': True, 'name': 'pearson_baseline'}
# 6  {'RMSE': 0.953927740797}   {'user_based': True, 'name': 'pearson_baseline'}
# 8  {'RMSE': 0.953954509175}  {'shrinkage': 150, 'name': 'pearson_baseline',...
# 1  {'RMSE': 0.958868664845}                {'user_based': True, 'name': 'msd'}
# 5  {'RMSE': 0.960090982799}            {'user_based': True, 'name': 'pearson'}
# 3  {'RMSE': 0.963703733825}             {'user_based': True, 'name': 'cosine'}
# 0  {'RMSE': 0.965244143768}                {'user_based': True, 'name': 'msd'}
# 4  {'RMSE': 0.967996976952}            {'user_based': True, 'name': 'pearson'}
# 2  {'RMSE': 0.973060700048}             {'user_based': True, 'name': 'cosine'}
# ■ Algorithm properties:
# surprise.prediction_algorithms.knns.KNNWithMeans at 0x7fe9f655e240 (
#     bsl_options = {},
#     k = 40,
#     min_k = 1,
#     sim_options = {'shrinkage': 150, 'name': 'pearson_baseline', 'user_based': True},
#     verbose = True
# )
# ■ Training using trainset
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# ■ Evaluating using testset
# RMSE: 0.9362
# ■ Using the best estimator on full dataset
# ■ Saving the trained model
# The dump has been saved as file /home/local/FRAMGIA/nguyen.ngoc.vinh/code/recommender/experiments/trained_models/knn_with_means
# ■ Accuracy scores:
# MAE:  0.6416
# RMSE: 0.8275
# ■ Time elapsed: 0:01:31
# ■ Recommendations:
# |    | 1                              | 2                              | 3                              |
# |----+--------------------------------+--------------------------------+--------------------------------|
# |  0 | {'iid': '1167', 'est': '5.00'} | {'iid': '1127', 'est': '5.00'} | {'iid': '1597', 'est': '4.65'} |
# |  1 | {'iid': '1367', 'est': '5.00'} | {'iid': '1131', 'est': '5.00'} | {'iid': '1368', 'est': '4.60'} |
# |  2 | {'iid': '1405', 'est': '5.00'} | {'iid': '947', 'est': '5.00'}  | {'iid': '1449', 'est': '4.56'} |
# |  3 | {'iid': '851', 'est': '5.00'}  | {'iid': '868', 'est': '5.00'}  | {'iid': '1491', 'est': '4.48'} |
# |  4 | {'iid': '814', 'est': '5.00'}  | {'iid': '851', 'est': '5.00'}  | {'iid': '1591', 'est': '4.34'} |
# |  5 | {'iid': '1503', 'est': '5.00'} | {'iid': '1512', 'est': '5.00'} | {'iid': '1431', 'est': '4.28'} |
# |  6 | {'iid': '1629', 'est': '5.00'} | {'iid': '1368', 'est': '5.00'} | {'iid': '1429', 'est': '4.28'} |
# |  7 | {'iid': '1628', 'est': '5.00'} | {'iid': '1491', 'est': '5.00'} | {'iid': '1347', 'est': '4.18'} |
# |  8 | {'iid': '1282', 'est': '5.00'} | {'iid': '814', 'est': '5.00'}  | {'iid': '1599', 'est': '4.14'} |
# |  9 | {'iid': '1193', 'est': '5.00'} | {'iid': '1431', 'est': '5.00'} | {'iid': '1131', 'est': '4.13'} |

# %% [markdown]
# ### Non-negative Matrix Factorization

# %%
# %run experiments/nmf.py
# Out:
# ■ ■ ■ NMF ■ ■ ■
# ■ Performing random sampling on the dataset
# ■ Performing Grid Search
# ------------
# Parameters combination 1 of 4
# params:  {'n_factors': 15, 'n_epochs': 50}
# ------------
# Mean RMSE: 0.9757
# ------------
# ------------
# Parameters combination 2 of 4
# params:  {'n_factors': 15, 'n_epochs': 100}
# ------------
# Mean RMSE: 0.9731
# ------------
# ------------
# Parameters combination 3 of 4
# params:  {'n_factors': 20, 'n_epochs': 50}
# ------------
# Mean RMSE: 0.9790
# ------------
# ------------
# Parameters combination 4 of 4
# params:  {'n_factors': 20, 'n_epochs': 100}
# ------------
# Mean RMSE: 0.9728
# ------------
# ■ Grid Search completed. Here is the summary:
#        RMSE  n_factors                              params  \
# 3  0.972774         20  {'n_factors': 20, 'n_epochs': 100}
# 1  0.973061         15  {'n_factors': 15, 'n_epochs': 100}
# 0  0.975731         15   {'n_factors': 15, 'n_epochs': 50}
# 2  0.978975         20   {'n_factors': 20, 'n_epochs': 50}
#
#                      scores
# 3  {'RMSE': 0.972773716529}
# 1  {'RMSE': 0.973061208647}
# 0  {'RMSE': 0.975731133626}
# 2  {'RMSE': 0.978975075909}
# ■ Algorithm properties:
# surprise.prediction_algorithms.matrix_factorization.NMF at 0x7fe9f0fead30 (
#     biased = False,
#     bsl_options = {},
#     init_high = 1,
#     init_low = 0,
#     lr_bi = 0.005,
#     ...,
#     reg_pu = 0.06,
#     reg_qi = 0.06,
#     sim_options = {'user_based': True},
#     verbose = True
# )
# ■ Training using trainset
# Processing epoch 0
# Processing epoch 1
# Processing epoch 2
# Processing epoch 3
# Processing epoch 4
# Processing epoch 5
# Processing epoch 6
# Processing epoch 7
# Processing epoch 8
# Processing epoch 9
# Processing epoch 10
# Processing epoch 11
# Processing epoch 12
# Processing epoch 13
# Processing epoch 14
# Processing epoch 15
# Processing epoch 16
# Processing epoch 17
# Processing epoch 18
# Processing epoch 19
# Processing epoch 20
# Processing epoch 21
# Processing epoch 22
# Processing epoch 23
# Processing epoch 24
# Processing epoch 25
# Processing epoch 26
# Processing epoch 27
# Processing epoch 28
# Processing epoch 29
# Processing epoch 30
# Processing epoch 31
# Processing epoch 32
# Processing epoch 33
# Processing epoch 34
# Processing epoch 35
# Processing epoch 36
# Processing epoch 37
# Processing epoch 38
# Processing epoch 39
# Processing epoch 40
# Processing epoch 41
# Processing epoch 42
# Processing epoch 43
# Processing epoch 44
# Processing epoch 45
# Processing epoch 46
# Processing epoch 47
# Processing epoch 48
# Processing epoch 49
# Processing epoch 50
# Processing epoch 51
# Processing epoch 52
# Processing epoch 53
# Processing epoch 54
# Processing epoch 55
# Processing epoch 56
# Processing epoch 57
# Processing epoch 58
# Processing epoch 59
# Processing epoch 60
# Processing epoch 61
# Processing epoch 62
# Processing epoch 63
# Processing epoch 64
# Processing epoch 65
# Processing epoch 66
# Processing epoch 67
# Processing epoch 68
# Processing epoch 69
# Processing epoch 70
# Processing epoch 71
# Processing epoch 72
# Processing epoch 73
# Processing epoch 74
# Processing epoch 75
# Processing epoch 76
# Processing epoch 77
# Processing epoch 78
# Processing epoch 79
# Processing epoch 80
# Processing epoch 81
# Processing epoch 82
# Processing epoch 83
# Processing epoch 84
# Processing epoch 85
# Processing epoch 86
# Processing epoch 87
# Processing epoch 88
# Processing epoch 89
# Processing epoch 90
# Processing epoch 91
# Processing epoch 92
# Processing epoch 93
# Processing epoch 94
# Processing epoch 95
# Processing epoch 96
# Processing epoch 97
# Processing epoch 98
# Processing epoch 99
# ■ Evaluating using testset
# RMSE: 0.9627
# ■ Using the best estimator on full dataset
# ■ Saving the trained model
# The dump has been saved as file /home/local/FRAMGIA/nguyen.ngoc.vinh/code/recommender/experiments/trained_models/nmf
# ■ Accuracy scores:
# MAE:  0.8202
# RMSE: 1.0410
# ■ Time elapsed: 0:00:33
# ■ Recommendations:
# |    | 1                              | 2                              | 3                              |
# |----+--------------------------------+--------------------------------+--------------------------------|
# |  0 | {'iid': '114', 'est': '5.00'}  | {'iid': '1643', 'est': '5.00'} | {'iid': '904', 'est': '4.27'}  |
# |  1 | {'iid': '408', 'est': '5.00'}  | {'iid': '1500', 'est': '5.00'} | {'iid': '854', 'est': '4.26'}  |
# |  2 | {'iid': '1449', 'est': '5.00'} | {'iid': '543', 'est': '4.90'}  | {'iid': '1449', 'est': '4.25'} |
# |  3 | {'iid': '483', 'est': '4.98'}  | {'iid': '318', 'est': '4.81'}  | {'iid': '921', 'est': '4.19'}  |
# |  4 | {'iid': '1643', 'est': '4.96'} | {'iid': '1122', 'est': '4.72'} | {'iid': '902', 'est': '4.10'}  |
# |  5 | {'iid': '884', 'est': '4.92'}  | {'iid': '1064', 'est': '4.71'} | {'iid': '1607', 'est': '4.09'} |
# |  6 | {'iid': '119', 'est': '4.91'}  | {'iid': '1449', 'est': '4.70'} | {'iid': '285', 'est': '4.03'}  |
# |  7 | {'iid': '1368', 'est': '4.91'} | {'iid': '1062', 'est': '4.69'} | {'iid': '6', 'est': '4.02'}    |
# |  8 | {'iid': '641', 'est': '4.87'}  | {'iid': '515', 'est': '4.65'}  | {'iid': '1512', 'est': '4.01'} |
# |  9 | {'iid': '357', 'est': '4.82'}  | {'iid': '408', 'est': '4.64'}  | {'iid': '524', 'est': '4.00'}  |

# %% [markdown]
# ### SlopeOne

# %%
# %run experiments/slope_one.py
# Out:
# ■ ■ ■ SlopeOne ■ ■ ■
# ■ Performing random sampling on the dataset
# ■ Performing Grid Search
# ------------
# Parameters combination 1 of 1
# params:  {}
# ------------
# Mean RMSE: 0.9506
# ------------
# ■ Grid Search completed. Here is the summary:
#   params                   scores
# 0     {}  {'RMSE': 0.95062169723}
# ■ Algorithm properties:
# surprise.prediction_algorithms.slope_one.SlopeOne at 0x7fe9ebee2c50 (
#     bsl_options = {},
#     sim_options = {'user_based': True},
#     verbose = True
# )
# ■ Training using trainset
# ■ Evaluating using testset
# RMSE: 0.9437
# ■ Using the best estimator on full dataset
# ■ Saving the trained model
# The dump has been saved as file /home/local/FRAMGIA/nguyen.ngoc.vinh/code/recommender/experiments/trained_models/slope_one
# ■ Accuracy scores:
# MAE:  0.7423
# RMSE: 0.9437
# ■ Time elapsed: 0:01:25
# ■ Recommendations:
# |    | 1                              | 2                              | 3                              |
# |----+--------------------------------+--------------------------------+--------------------------------|
# |  0 | {'iid': '1512', 'est': '5.00'} | {'iid': '1512', 'est': '5.00'} | {'iid': '1512', 'est': '5.00'} |
# |  1 | {'iid': '1293', 'est': '5.00'} | {'iid': '838', 'est': '5.00'}  | {'iid': '814', 'est': '5.00'}  |
# |  2 | {'iid': '814', 'est': '5.00'}  | {'iid': '814', 'est': '5.00'}  | {'iid': '868', 'est': '4.96'}  |
# |  3 | {'iid': '1653', 'est': '5.00'} | {'iid': '1450', 'est': '5.00'} | {'iid': '1500', 'est': '4.71'} |
# |  4 | {'iid': '1599', 'est': '5.00'} | {'iid': '1175', 'est': '5.00'} | {'iid': '1529', 'est': '4.53'} |
# |  5 | {'iid': '1500', 'est': '5.00'} | {'iid': '1599', 'est': '5.00'} | {'iid': '1653', 'est': '4.48'} |
# |  6 | {'iid': '1643', 'est': '5.00'} | {'iid': '1500', 'est': '5.00'} | {'iid': '1175', 'est': '4.38'} |
# |  7 | {'iid': '1592', 'est': '4.99'} | {'iid': '1467', 'est': '5.00'} | {'iid': '1593', 'est': '4.38'} |
# |  8 | {'iid': '1467', 'est': '4.95'} | {'iid': '1293', 'est': '4.97'} | {'iid': '1452', 'est': '4.33'} |
# |  9 | {'iid': '1367', 'est': '4.86'} | {'iid': '1449', 'est': '4.94'} | {'iid': '1458', 'est': '4.33'} |

# %% [markdown]
# ### SVD

# %%
# %run experiments/svd.py
# Out:
# ■ ■ ■ SVD ■ ■ ■
# ■ Performing random sampling on the dataset
# ■ Performing Grid Search
# ------------
# Parameters combination 1 of 4
# params:  {'n_factors': 100, 'reg_all': 0.01}
# ------------
# Mean RMSE: 0.9531
# ------------
# ------------
# Parameters combination 2 of 4
# params:  {'n_factors': 100, 'reg_all': 0.02}
# ------------
# Mean RMSE: 0.9469
# ------------
# ------------
# Parameters combination 3 of 4
# params:  {'n_factors': 150, 'reg_all': 0.01}
# ------------
# Mean RMSE: 0.9577
# ------------
# ------------
# Parameters combination 4 of 4
# params:  {'n_factors': 150, 'reg_all': 0.02}
# ------------
# Mean RMSE: 0.9518
# ------------
# ■ Grid Search completed. Here is the summary:
#        RMSE  n_factors                               params  \
# 1  0.946856        100  {'n_factors': 100, 'reg_all': 0.02}
# 3  0.951814        150  {'n_factors': 150, 'reg_all': 0.02}
# 0  0.953128        100  {'n_factors': 100, 'reg_all': 0.01}
# 2  0.957687        150  {'n_factors': 150, 'reg_all': 0.01}
#
#                      scores
# 1  {'RMSE': 0.946855501396}
# 3  {'RMSE': 0.951814012855}
# 0  {'RMSE': 0.953127830913}
# 2  {'RMSE': 0.957686745064}
# ■ Algorithm properties:
# surprise.prediction_algorithms.matrix_factorization.SVD at 0x7fea01cd8e80 (
#     biased = True,
#     bsl_options = {},
#     init_mean = 0,
#     init_std_dev = 0.1,
#     lr_bi = 0.005,
#     ...,
#     reg_pu = 0.02,
#     reg_qi = 0.02,
#     sim_options = {'user_based': True},
#     verbose = True
# )
# ■ Training using trainset
# Processing epoch 0
# Processing epoch 1
# Processing epoch 2
# Processing epoch 3
# Processing epoch 4
# Processing epoch 5
# Processing epoch 6
# Processing epoch 7
# Processing epoch 8
# Processing epoch 9
# Processing epoch 10
# Processing epoch 11
# Processing epoch 12
# Processing epoch 13
# Processing epoch 14
# Processing epoch 15
# Processing epoch 16
# Processing epoch 17
# Processing epoch 18
# Processing epoch 19
# ■ Evaluating using testset
# RMSE: 0.9352
# ■ Using the best estimator on full dataset
# ■ Saving the trained model
# The dump has been saved as file /home/local/FRAMGIA/nguyen.ngoc.vinh/code/recommender/experiments/trained_models/svd
# ■ Accuracy scores:
# MAE:  0.4618
# RMSE: 0.5877
# ■ Time elapsed: 0:00:33
# ■ Recommendations:
# |    | 1                              | 2                             | 3                             |
# |----+--------------------------------+-------------------------------+-------------------------------|
# |  0 | {'iid': '963', 'est': '4.90'}  | {'iid': '318', 'est': '4.64'} | {'iid': '50', 'est': '4.41'}  |
# |  1 | {'iid': '474', 'est': '4.88'}  | {'iid': '64', 'est': '4.62'}  | {'iid': '285', 'est': '4.21'} |
# |  2 | {'iid': '190', 'est': '4.87'}  | {'iid': '127', 'est': '4.58'} | {'iid': '169', 'est': '4.19'} |
# |  3 | {'iid': '12', 'est': '4.83'}   | {'iid': '427', 'est': '4.53'} | {'iid': '603', 'est': '4.13'} |
# |  4 | {'iid': '285', 'est': '4.80'}  | {'iid': '12', 'est': '4.52'}  | {'iid': '647', 'est': '4.12'} |
# |  5 | {'iid': '511', 'est': '4.68'}  | {'iid': '408', 'est': '4.51'} | {'iid': '172', 'est': '4.10'} |
# |  6 | {'iid': '199', 'est': '4.64'}  | {'iid': '483', 'est': '4.50'} | {'iid': '474', 'est': '4.10'} |
# |  7 | {'iid': '661', 'est': '4.63'}  | {'iid': '169', 'est': '4.49'} | {'iid': '57', 'est': '4.10'}  |
# |  8 | {'iid': '1194', 'est': '4.58'} | {'iid': '174', 'est': '4.47'} | {'iid': '114', 'est': '4.10'} |
# |  9 | {'iid': '435', 'est': '4.54'}  | {'iid': '479', 'est': '4.47'} | {'iid': '513', 'est': '4.07'} |

# %% [markdown]
# ### SVD++

# %%
# %run experiments/svdpp.py
# Out:
# ■ ■ ■ SVDpp ■ ■ ■
# ■ Performing random sampling on the dataset
# ■ Performing Grid Search
# ------------
# Parameters combination 1 of 4
# params:  {'n_epochs': 10, 'reg_all': 0.01}
# ------------
# Mean RMSE: 0.9293
# ------------
# ------------
# Parameters combination 2 of 4
# params:  {'n_epochs': 20, 'reg_all': 0.01}
# ------------
# Mean RMSE: 0.9306
# ------------
# ------------
# Parameters combination 3 of 4
# params:  {'n_epochs': 10, 'reg_all': 0.02}
# ------------
# Mean RMSE: 0.9342
# ------------
# ------------
# Parameters combination 4 of 4
# params:  {'n_epochs': 20, 'reg_all': 0.02}
# ------------
# Mean RMSE: 0.9277
# ------------
# ■ Grid Search completed. Here is the summary:
#        RMSE  n_epochs                             params  \
# 3  0.927684        20  {'n_epochs': 20, 'reg_all': 0.02}
# 0  0.929325        10  {'n_epochs': 10, 'reg_all': 0.01}
# 1  0.930557        20  {'n_epochs': 20, 'reg_all': 0.01}
# 2  0.934234        10  {'n_epochs': 10, 'reg_all': 0.02}
#
#                      scores
# 3  {'RMSE': 0.927684061565}
# 0  {'RMSE': 0.929324680553}
# 1  {'RMSE': 0.930557456971}
# 2  {'RMSE': 0.934233645883}
# ■ Algorithm properties:
# surprise.prediction_algorithms.matrix_factorization.SVDpp at 0x7fe9eaa79390 (
#     bsl_options = {},
#     init_mean = 0,
#     init_std_dev = 0.1,
#     lr_bi = 0.007,
#     lr_bu = 0.007,
#     ...,
#     reg_qi = 0.02,
#     reg_yj = 0.02,
#     sim_options = {'user_based': True},
#     verbose = True
# )
# ■ Training using trainset
#  processing epoch 0
#  processing epoch 1
#  processing epoch 2
#  processing epoch 3
#  processing epoch 4
#  processing epoch 5
#  processing epoch 6
#  processing epoch 7
#  processing epoch 8
#  processing epoch 9
#  processing epoch 10
#  processing epoch 11
#  processing epoch 12
#  processing epoch 13
#  processing epoch 14
#  processing epoch 15
#  processing epoch 16
#  processing epoch 17
#  processing epoch 18
#  processing epoch 19
# ■ Evaluating using testset
# RMSE: 0.9209
# ■ Using the best estimator on full dataset
# ■ Saving the trained model
# The dump has been saved as file /home/local/FRAMGIA/nguyen.ngoc.vinh/code/recommender/experiments/trained_models/svdpp
# ■ Accuracy scores:
# MAE:  0.5024
# RMSE: 0.6391
# ■ Time elapsed: 0:02:11
# ■ Recommendations:
# |    | 1                             | 2                              | 3                              |
# |----+-------------------------------+--------------------------------+--------------------------------|
# |  0 | {'iid': '302', 'est': '5.00'} | {'iid': '408', 'est': '4.84'}  | {'iid': '169', 'est': '3.93'}  |
# |  1 | {'iid': '511', 'est': '5.00'} | {'iid': '169', 'est': '4.65'}  | {'iid': '315', 'est': '3.80'}  |
# |  2 | {'iid': '179', 'est': '4.98'} | {'iid': '9', 'est': '4.65'}    | {'iid': '100', 'est': '3.79'}  |
# |  3 | {'iid': '474', 'est': '4.92'} | {'iid': '483', 'est': '4.63'}  | {'iid': '320', 'est': '3.78'}  |
# |  4 | {'iid': '483', 'est': '4.91'} | {'iid': '1449', 'est': '4.63'} | {'iid': '316', 'est': '3.74'}  |
# |  5 | {'iid': '408', 'est': '4.89'} | {'iid': '511', 'est': '4.61'}  | {'iid': '641', 'est': '3.74'}  |
# |  6 | {'iid': '661', 'est': '4.89'} | {'iid': '114', 'est': '4.59'}  | {'iid': '657', 'est': '3.73'}  |
# |  7 | {'iid': '268', 'est': '4.82'} | {'iid': '474', 'est': '4.57'}  | {'iid': '1194', 'est': '3.71'} |
# |  8 | {'iid': '512', 'est': '4.80'} | {'iid': '318', 'est': '4.54'}  | {'iid': '83', 'est': '3.69'}   |
# |  9 | {'iid': '654', 'est': '4.79'} | {'iid': '513', 'est': '4.53'}  | {'iid': '528', 'est': '3.68'}  |

# %% [markdown]
# ### Visualizing the movie-lens dataset

# %%
import os
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt

def load_data_into_dataframe(path):
    if not os.path.exists(path):
        raise RuntimeError('Cannot find the given dataset!')
    df = pd.read_csv(path, sep='\t', names=['UserID', 'ItemID', 'Rating', 'Timestamp'])
    return df

path = os.path.expanduser('~/.surprise_data/ml-100k/ml-100k/u.data')
df = load_data_into_dataframe(path)

# %%
print(df.shape)
# Out:
# (100000, 4)

# %%
print(df.columns)
# Out:
# Index(['UserID', 'ItemID', 'Rating', 'Timestamp'], dtype='object')

# %%
print(df.head())
# Out:
#    UserID  ItemID  Rating  Timestamp
# 0     196     242       3  881250949
# 1     186     302       3  891717742
# 2      22     377       1  878887116
# 3     244      51       2  880606923
# 4     166     346       1  886397596

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 4 columns):
# UserID       100000 non-null int64
# ItemID       100000 non-null int64
# Rating       100000 non-null int64
# Timestamp    100000 non-null int64
# dtypes: int64(4)
# memory usage: 3.1 MB
# None

# %%
print(df.describe())
# Out:
#              UserID         ItemID         Rating     Timestamp
# count  100000.00000  100000.000000  100000.000000  1.000000e+05
# mean      462.48475     425.530130       3.529860  8.835289e+08
# std       266.61442     330.798356       1.125674  5.343856e+06
# min         1.00000       1.000000       1.000000  8.747247e+08
# 25%       254.00000     175.000000       3.000000  8.794487e+08
# 50%       447.00000     322.000000       4.000000  8.828269e+08
# 75%       682.00000     631.000000       4.000000  8.882600e+08
# max       943.00000    1682.000000       5.000000  8.932866e+08

# %%
plt.hist(df['Rating'])
# Out:
# (array([  6110.,      0.,  11370.,      0.,      0.,  27145.,      0.,
#          34174.,      0.,  21201.]),
#  array([ 1. ,  1.4,  1.8,  2.2,  2.6,  3. ,  3.4,  3.8,  4.2,  4.6,  5. ]),
#  <a list of 10 Patch objects>)

# %%
df.groupby(['Rating'])['UserID'].count()
# Out:
# Rating
# 1     6110
# 2    11370
# 3    27145
# 4    34174
# 5    21201
# Name: UserID, dtype: int64

# %%
plt.hist(df.groupby(['ItemID'])['ItemID'].count())
# Out:
# (array([  1.14600000e+03,   2.49000000e+02,   1.39000000e+02,
#           6.70000000e+01,   3.80000000e+01,   2.40000000e+01,
#           7.00000000e+00,   5.00000000e+00,   6.00000000e+00,
#           1.00000000e+00]),
#  array([   1. ,   59.2,  117.4,  175.6,  233.8,  292. ,  350.2,  408.4,
#          466.6,  524.8,  583. ]),
#  <a list of 10 Patch objects>)
